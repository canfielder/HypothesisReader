# %% [markdown]
# # Purpose
# The purpose of this notebook is to execute a grid search like evaluation of different Entity Extraction model parameters. This is the second iteration, and will implement parameters from the first iteration.
#
# **Parameters Selected Based on Iteration 1**:
#
# * **Embedding**: Glove
# * **Stopwords**: False
# * **Lemmatization**: False
# * **LSTM Stack**: True
# * **Sample Weights**: False
# * **Trainable**: True
#
# **Parameters to Evaluate:**
# * Hidden Dimension(s)
# * Dropout Rate

# %% [markdown]
# ## Import

# %% [markdown]
# ### Packages

# %%
# General
import codecs, io, os, re, sys, time
from collections import OrderedDict 
from scipy.stats import uniform
from tqdm import tqdm

# Analysis
import numpy as np
import pandas as pd
from sklearn.metrics import \
    accuracy_score, classification_report, confusion_matrix, \
    precision_recall_fscore_support
from sklearn.model_selection import \
    ParameterGrid, RandomizedSearchCV, RepeatedStratifiedKFold
from sklearn.utils.class_weight import compute_class_weight

# Visual
# import matplotlib.pyplot as plt
# import seaborn as sn

# Deep Learning
import tensorflow as tf
from keras.wrappers.scikit_learn import KerasClassifier
from keras.callbacks import EarlyStopping
from keras.layers.experimental.preprocessing import TextVectorization

# %% [markdown]
# ### Custom Functions

# %%
sys.path.append('*')
from source_entity_extraction import *
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\canfi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\canfi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Data
# The training data is imported and the necessary columns are converted to lists.

# %%
#import data
path_dir_data = "./../data"
subfolder_a = "input"
file_training_data = "training_data_dir_multiclass.xlsx"
path_training_data = os.path.join(path_dir_data, subfolder_a, file_training_data)
dataset = pd.read_excel(path_training_data,  engine='openpyxl')

#convert into lists
df = pd.DataFrame({
    'text': dataset.sentence, 
    'node1': dataset.node_1, 
    'node2': dataset.node_2
    })

df.dropna(inplace = True)

# %% [markdown]
# ## Randomness
# To better control and compare results of the Entity Extraction model between the environments where the model is trainined (Python) and where it will be implemented (R/Shiny), we will attempt to control any random actions by the process to maintain consistent results.

# %%
random_state = 5590
np.random.seed(random_state)
tf.random.set_seed(random_state)

# %% [markdown]
# # Global Actions
# The following section defines global settings or performs actions that are consistent across the entirety of this notebook.

# %% [markdown]
# ## Variables
# Varaibles that are used across multiple calls should be defined here.

# %%
MAX_LENGTH = 50
MAX_FEATURES = 1000
BATCH_SIZE = 32
LEMMATIZE = False
STOP_WORDS = False
SAMPLE_WEIGHTS = False
TRAINABLE = True
EMBEDDING_LABELS = [
    "text_vectorization",
    "glove",
    "fasttext"
]

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# ### Text Processing

# %%
df = process_text(
    df, 
    stopwords = LEMMATIZE,
    lemmatize = STOP_WORDS
    )

# %% [markdown]
# ### Target Generation
# With the text processing complete we will now create two versions of the target set. The first will have the feature tokens converted into numerical representations for each class: 0, 1, 2. Then we will also create a target set that is a one-hot-encoded representation of the numerical classes.

# %%
df = target_gen_wrapper(
    df, 
    max_length=MAX_LENGTH
    )

# %% [markdown]
# ## Split Data into Training / Test Sets

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(
    df,
    test_size=0.25, 
    random_state = random_state
    )

# %% [markdown]
# Due to the different nature of random actions between R and Python, it is easier to export the test set than to duplciate the train/test split.

# %%
subfolder_b = "output"
subfolder_entity = "entity_extraction"
file_name = 'entity_extraction_test_set.csv'
path = os.path.join(path_dir_data, subfolder_b, 
                    subfolder_entity, file_name)
df_test.to_csv(path, index_label=False)

# %% [markdown]
# # Feature/Target Definition
# We need to define a target variable and perform preprocessing steps on the features before inputting into the model

# %%
# Features
X_train = df_train['text'].tolist()
X_test = df_test['text'].tolist()

# Targets
y_train_val = df_train['target_labels'].tolist()
y_test_val = df_test['target_labels'].tolist()

# %% [markdown]
# ### Export Target Classes
# To simplify eventual work in R, we will generate the our target classes the test dataset and export it.

# %%
# Export Test Target Values
# Set File Location
file_name = 'entity_extraction_test_target_classes_cause_effect.csv'
path = os.path.join(path_dir_data, subfolder_b, subfolder_entity, file_name)

# Convert Lists to Dataframe
df_targets_test = pd.DataFrame(y_test_val)

# Export Target Values
df_targets_test.to_csv(path, index=False, header=False)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Vectorization Layer

# %%
vectorization_layer = TextVectorization(
    max_tokens=MAX_FEATURES,
    output_mode='int',
    output_sequence_length=MAX_LENGTH
    )

vectorization_layer.adapt(X_train)

vocab = vectorization_layer.get_vocabulary()
vocab_len = len(vocab)
print(f"Vocabulary Size: {vocab_len}")
# Out:
# Vocabulary Size: 1000

# %%
# Inspect vocabulary
word_index = dict(zip(vocab, range(len(vocab))))
# word_index

# %%
# # Inspect vectorization output
# m = 5
# test_string = X_train[m]
# print(f"Test String - Raw:\n{test_string}")
# print()
# test_string_vec = vectorization_layer([test_string])
# print(f"Test String - Vectorized:\n{test_string_vec[0]}")

# %% [markdown]
# ## Embedding Layer

# %% [markdown]
# ### Initialize

# %%
dct_embedding_index = {}

# Initialize None for text vectorizaiton
dct_embedding_index["text_vectorization"] = {
    "index": None,
    "dimension": None
}

dct_embedding_matrix = {
    "text_vectorization": None
}

# %% [markdown]
# ### Embedding Matrix

# %% [markdown]
# ### Glove

# %% [markdown]
# ##### Import/Load Embeddings

# %%
embed_label = EMBEDDING_LABELS[1]
embedding_dim = 100

# Define file path
subfolder_embed = "pre_trained"
subfolder_embed_glove = "glove.6B"
file_name = "glove.6B.100d.txt"
path = os.path.join(path_dir_data, subfolder_embed, subfolder_embed_glove, file_name)

print("Preparing embedding index...")
embeddings_index = {}
with open(path, encoding="utf8") as f:
    for line in tqdm(f):
        word, coefs = line.split(maxsplit=1)
        coefs = np.fromstring(coefs, "f", sep=" ")
        embeddings_index[word] = coefs

dct_embedding_index[embed_label] = {
    "index": embeddings_index,
    "dimension": embedding_dim
}
print(f"Found {len(embeddings_index)} word vectors.")
# Out:
# 942it [00:00, 9419.83it/s]
# Preparing embedding index...
# 400000it [00:36, 11085.83it/s]
# Found 400000 word vectors.

# %% [markdown]
# ##### Create Matrix

# %%
embedding_matrix = gen_embedding_matrix(
    dct_embedding_index = dct_embedding_index,
    embed_label = embed_label, 
    vocabulary_length = vocab_len, 
    word_index = word_index
)

dct_embedding_matrix[embed_label] = embedding_matrix

# %% [markdown]
# #### FastText

# %% [markdown]
# ##### Import/Load Embeddings

# %%
# embed_label = EMBEDDING_LABELS[2]
# embedding_dim = 300

# # Define file path
# subfolder_embed = "pre_trained"
# subfolder_embed_fasttext = "wiki-news-300d-1M.vec"
# file_name = "wiki-news-300d-1M.vec"
# path = os.path.join(path_dir_data, subfolder_embed, subfolder_embed_fasttext, file_name)
# f = codecs.open(path, encoding='utf-8')

# print("Preparing embedding index...")
# embeddings_index = {}
# for line in tqdm(f):
#     values = line.rstrip().rsplit(' ')
#     # print(values)
#     word = values[0]
#     # print(word)
#     coefs = np.asarray(values[1:], dtype='float32')
#     # print(coefs)
#     embeddings_index[word] = coefs
# f.close()

# dct_embedding_index[embed_label] = {
#     "index": embeddings_index,
#     "dimension": embedding_dim,
# }
# print(f'Found {len(embeddings_index)} word vectors.')

# %% [markdown]
# ##### Create Matrix

# %%
# embedding_matrix = gen_embedding_matrix(
#     dct_embedding_index = dct_embedding_index,
#     embed_label = embed_label, 
#     vocabulary_length = vocab_len, 
#     word_index = word_index
# )

# dct_embedding_matrix[embed_label] = embedding_matrix

# %% [markdown]
# ## Imbalance Class Management
# There is an imbalance in the classes predicted by the model. Roughly 90% of tokens are class 0 (not Cause or Entity node, filler words). The remaining classes (1: Cause, 2: Entity) account for about 5% of the remaining tokens, each.
#
# In order to better predict all classes in the dataset, and not create a model which simply predicts the default class, we need to weight each of these classes differently. Unfortunately, we cannot simply use the **class weights** input for training a Keras model. that is because we are predicting a 3D array as an output, and Keras will not allow the use of **class weights** in such a case.
#
# There is a workaround, as discussed in Keras Github issue 3653. We can use **sample weights**, with the sample weights mode set to *temporal*.
#
# https://github.com/keras-team/keras/issues/3653
#
# To apply sample weights to our model, we needa matrix of sample weights to account for all input values. This matrix will be the same size as the y_train output array (n samples X sample length).

# %% [markdown]
# ### Sample Weights

# %%
# # Initialize Sample weight matrix
# sample_weight_matrix = np.array(y_train_val).copy()

# # Flatten matrix
# sample_weight_matrix_fl = flatten_list(sample_weight_matrix)

# # Determine number of classes
# n_classes = np.unique(sample_weight_matrix_fl).shape[0]

# # Determine class weights
# class_weights = compute_class_weight(
#     "balanced", 
#     np.unique(sample_weight_matrix_fl), 
#     np.array(sample_weight_matrix_fl)
#     )

# # Replace class label with class weight
# for i in range(0, len(class_weights)):
#     sample_weight_matrix = np.where(
#             sample_weight_matrix==i, 
#             class_weights[i], 
#             sample_weight_matrix
#             )

# %% [markdown]
# # Grid

# %% [markdown]
# ## Define Parameter Grid

# %%
params = {
    'embedding': ['glove'],
    'stop_words': [False],
    'lemmatization': [False],
    'hidden_dim_1': [32, 64, 128, 256],
    'hidden_dim_2': [32, 64, 128, 256],
    'lstm_stack': [True],
    'dropout': [True],
    'dropout_rate': [0.1, 0.25, 0.5],
    'sample_weights': [False],
    'trainable':  [True],
    }
param_grid = list(ParameterGrid(params))
print(f"Number of Parameter Configurations: {len(param_grid)}")
# Out:
# Number of Parameter Configurations: 48

# %% [markdown]
# ## Initialize Output Dictionary

# %%
# Initialize
dct_summary = OrderedDict()

dct_summary["embedding"] = []
dct_summary["stop_words"] = []
dct_summary["lemmatization"] = []
dct_summary["hidden_dim_1"] = []
dct_summary["hidden_dim_2"] = []
dct_summary["lstm_stack"] = []
dct_summary["dropout"] = []
dct_summary["dropout_rate"] = []
dct_summary["sample_weights"] = []
dct_summary["trainable"] = []
dct_summary["accuracy"] = []
dct_summary["precision_0"] = []
dct_summary["precision_1"] = []
dct_summary["precision_2"] = []
dct_summary["precision_macro"] = []
dct_summary["recall_0"] = []
dct_summary["recall_1"] = []
dct_summary["recall_2"] = []
dct_summary["recall_macro"] = []
dct_summary["f1_0"] = []
dct_summary["f1_1"] = []
dct_summary["f1_2"] = []
dct_summary["f1_macro"] = []

# %% [markdown]
# ## Execute Model Training/Evaluation

# %%
for i, param in enumerate(param_grid):

    # Define Parameters
    EMBEDDING = param['embedding']
    STOP_WORDS = param['stop_words']
    LEMMATIZATION = param['lemmatization']
    HIDDEN_DIM_1 = param['hidden_dim_1']
    HIDDEN_DIM_2 = param['hidden_dim_2']
    LSTM_STACK = param['lstm_stack']
    DROP_OUT = param['dropout']
    DROP_OUT_RATE = param['dropout_rate']
    SAMPLE_WEIGHTS = param['sample_weights']
    TRAINABLE = param['trainable']
    

    print(f"Iteration:\t{i + 1}")
    print(f"EMBEDDING:\t{EMBEDDING}")
    print(f"STOP_WORDS:\t{STOP_WORDS}")
    print(f"LEMMATIZATION:\t{LEMMATIZATION}")
    print(f"HIDDEN_DIM:\t{HIDDEN_DIM_1}")
    print(f"HIDDEN_DIM:\t{HIDDEN_DIM_2}")
    print(f"LSTM_STACK:\t{LSTM_STACK}")
    print(f"DROP_OUT:\t{DROP_OUT}")
    print(f"DROP_OUT:\t{DROP_OUT_RATE}")
    print(f"SAMPLE_WEIGHTS:\t{SAMPLE_WEIGHTS}")
    print(f"TRAINABLE:\t{TRAINABLE}")
    print()

    # Initialize input dataframe
    df_iter = df.copy()

    # Process ------------------------------------------------------------------
    # Process Text
    df_iter = process_text(
        df_iter, 
        stopwords = STOP_WORDS,
        lemmatize = LEMMATIZATION
    )

    # Generate Target Labels
    df_iter = target_gen_wrapper(
        df_iter, 
        max_length=MAX_LENGTH
        )
    
    # Split Training/Test Set
    df_train, df_test = train_test_split(
        df_iter,
        test_size=0.25, 
        random_state = random_state
        )
    
    # Define Target/Features
    # Features
    X_train = df_train['text'].tolist()
    X_test = df_test['text'].tolist()

    # Target
    y_train_val = df_train['target_labels'].tolist()
    y_test_val = df_test['target_labels'].tolist()

    # Build Model --------------------------------------------------------------
    # Vectorization Layer
    vectorization_layer = TextVectorization(
        max_tokens=MAX_FEATURES,
        output_mode='int',
        output_sequence_length=MAX_LENGTH
        )

    # Adapt to training data
    vectorization_layer.adapt(X_train)

    # Define vocabulary
    vocab = vectorization_layer.get_vocabulary()
    vocab_len = len(vocab)
    word_index = dict(zip(vocab, range(vocab_len)))

    # Create embedding matrix
    embedding_matrix = gen_embedding_matrix(
        dct_embedding_index = dct_embedding_index,
        embed_label = EMBEDDING, 
        vocabulary_length = vocab_len, 
        word_index = word_index
        )

    # Embedding Layer
    embedding_layer = gen_embedding_layer(
        label = EMBEDDING,
        input_dimension = vocab_len,
        output_dimension_wo_init = 64,
        max_length = MAX_LENGTH,
        embedding_matrix = embedding_matrix,
        trainable = TRAINABLE
        )

    # Compile Model
    model = compile_model(
        vectorization_layer = vectorization_layer,
        embedding_layer = embedding_layer,
        dropout = DROP_OUT,
        dropout_rate = DROP_OUT_RATE,
        lstm_stack = LSTM_STACK,
        hidden_dimension_1 = HIDDEN_DIM_1,
        hidden_dimension_2 = HIDDEN_DIM_2,
        sample_weights = SAMPLE_WEIGHTS
    )

    # Convert and encode target/features
    # # Convert features to numpy array from model input
    X_train = np.array(X_train)

    # Encode targets
    y_train = encode_target(y_train_val)

    # Convert target to numpy array for model input
    y_train = np.array(y_train)

    # Train Model --------------------------------------------------------------
    if SAMPLE_WEIGHTS: 
        history = model.fit(
                            X_train, y_train, 
                            batch_size=BATCH_SIZE, 
                            epochs=75, 
                            validation_split=0.2, 
                            sample_weight=sample_weight_matrix,
                            verbose=2
                            )
    else: 
        history = model.fit(
                            X_train, y_train, 
                            batch_size=BATCH_SIZE, 
                            epochs=75, 
                            validation_split=0.2, 
                            verbose=2
                            )
        
    # Evaluation ---------------------------------------------------------------
    # Generate Predictions
    y_pred = []
    for i in range(len(X_test)):
        y_pred_prob = model.predict(np.array([X_test[i]]))
        y_pred_class = np.argmax(y_pred_prob, axis=-1)[0].tolist()
        y_pred.append(y_pred_class)

    # Flatten lists
    y_pred = flatten_list(y_pred)
    y_test = flatten_list(y_test_val)

    # Score Model
    dct_summary = gen_eval_metrics(
        dct_summary,
        y_test, y_pred,
        embedding = EMBEDDING,
        stop_words = STOP_WORDS,
        lemmatization = LEMMATIZATION,
        hidden_dim_1 = HIDDEN_DIM_1,
        hidden_dim_2 = HIDDEN_DIM_2,
        lstm_stack = LSTM_STACK,
        dropout = DROP_OUT,
        dropout_rate = DROP_OUT_RATE,
        sample_weights = SAMPLE_WEIGHTS,
        trainable = TRAINABLE
        )
# Out:
# Iteration:	1
# EMBEDDING:	glove
# STOP_WORDS:	False
# LEMMATIZATION:	False
# HIDDEN_DIM:	32
# HIDDEN_DIM:	32
# LSTM_STACK:	True
# DROP_OUT:	True
# DROP_OUT:	0.1
# SAMPLE_WEIGHTS:	False
# TRAINABLE:	True
#
# Epoch 1/75
# 12/12 - 27s - loss: 0.3157 - accuracy: 0.5526 - val_loss: 0.2628 - val_accuracy: 0.6321
# Epoch 2/75
# 12/12 - 2s - loss: 0.2664 - accuracy: 0.6688 - val_loss: 0.2265 - val_accuracy: 0.6950
# Epoch 3/75
# 12/12 - 2s - loss: 0.2323 - accuracy: 0.7178 - val_loss: 0.2136 - val_accuracy: 0.6995
# Epoch 4/75
# 12/12 - 2s - loss: 0.2088 - accuracy: 0.7519 - val_loss: 0.1873 - val_accuracy: 0.7716
# Epoch 5/75
# 12/12 - 2s - loss: 0.1826 - accuracy: 0.7895 - val_loss: 0.1730 - val_accuracy: 0.7865
# Epoch 6/75
# Epoch 74/75
# 12/12 - 2s - loss: 0.0104 - accuracy: 0.9893 - val_loss: 0.1906 - val_accuracy: 0.8748
# Epoch 75/75
# 12/12 - 2s - loss: 0.0077 - accuracy: 0.9914 - val_loss: 0.1878 - val_accuracy: 0.8722
# Iteration:	2
# EMBEDDING:	glove
# STOP_WORDS:	False
# LEMMATIZATION:	False
# HIDDEN_DIM:	32
# HIDDEN_DIM:	64
# LSTM_STACK:	True
# DROP_OUT:	True
# DROP_OUT:	0.1
# SAMPLE_WEIGHTS:	False
# TRAINABLE:	True
#
# Epoch 1/75
# 12/12 - 20s - loss: 0.3124 - accuracy: 0.5422 - val_loss: 0.2569 - val_accuracy: 0.6502
# Epoch 2/75
# 12/12 - 2s - loss: 0.2632 - accuracy: 0.6717 - val_loss: 0.2157 - val_accuracy: 0.7138
# Epoch 3/75
# 12/12 - 2s - loss: 0.2219 - accuracy: 0.7386 - val_loss: 0.1976 - val_accuracy: 0.7242
# Epoch 4/75
# 12/12 - 2s - loss: 0.1974 - accuracy: 0.7675 - val_loss: 0.1752 - val_accuracy: 0.7820
# Epoch 5/75
# 12/12 - 2s - loss: 0.1772 - accuracy: 0.7985 - val_loss: 0.1567 - val_accuracy: 0.7988
# Epoch 6/75
# 12/12 - 1s - loss: 0.1605 - accuracy: 0.8170 - val_loss: 0.1546 - val_accuracy: 0.8066
# Epoch 7/75
# 12/12 - 2s - loss: 0.1427 - accuracy: 0.8474 - val_loss: 0.1443 - val_accuracy: 0.8326
# Epoch 8/75
# 12/12 - 2s - loss: 0.1314 - accuracy: 0.8565 - val_loss: 0.1400 - val_accuracy: 0.8313
# Epoch 9/75
# 12/12 - 2s - loss: 0.1232 - accuracy: 0.8675 - val_loss: 0.1325 - val_accuracy: 0.8378
# Epoch 10/75
# 12/12 - 2s - loss: 0.1033 - accuracy: 0.8927 - val_loss: 0.1293 - val_accuracy: 0.8501
# Epoch 11/75
# 12/12 - 2s - loss: 0.1027 - accuracy: 0.8889 - val_loss: 0.1313 - val_accuracy: 0.8443
# Epoch 12/75
# 12/12 - 2s - loss: 0.0988 - accuracy: 0.8930 - val_loss: 0.1251 - val_accuracy: 0.8488
# Epoch 13/75
# 12/12 - 2s - loss: 0.0807 - accuracy: 0.9173 - val_loss: 0.1335 - val_accuracy: 0.8436
# Epoch 14/75
# 12/12 - 2s - loss: 0.0805 - accuracy: 0.9176 - val_loss: 0.1290 - val_accuracy: 0.8514
# Epoch 15/75
# 12/12 - 2s - loss: 0.0741 - accuracy: 0.9211 - val_loss: 0.1338 - val_accuracy: 0.8482
# Epoch 16/75
# 12/12 - 2s - loss: 0.0714 - accuracy: 0.9262 - val_loss: 0.1365 - val_accuracy: 0.8378
# Epoch 17/75
# 12/12 - 2s - loss: 0.0659 - accuracy: 0.9323 - val_loss: 0.1310 - val_accuracy: 0.8585
# Epoch 18/75
# 12/12 - 2s - loss: 0.0593 - accuracy: 0.9360 - val_loss: 0.1376 - val_accuracy: 0.8592
# Epoch 19/75
# Epoch 65/75
# 12/12 - 2s - loss: 0.0086 - accuracy: 0.9902 - val_loss: 0.2178 - val_accuracy: 0.8663
# Epoch 66/75
# 12/12 - 2s - loss: 0.0086 - accuracy: 0.9893 - val_loss: 0.2062 - val_accuracy: 0.8728
# Epoch 67/75
# 12/12 - 2s - loss: 0.0077 - accuracy: 0.9899 - val_loss: 0.2172 - val_accuracy: 0.8676
# Epoch 68/75
# 12/12 - 2s - loss: 0.0077 - accuracy: 0.9910 - val_loss: 0.2229 - val_accuracy: 0.8631
# Epoch 69/75
# 12/12 - 2s - loss: 0.0073 - accuracy: 0.9930 - val_loss: 0.2257 - val_accuracy: 0.8676
# Epoch 70/75
# 12/12 - 2s - loss: 0.0074 - accuracy: 0.9901 - val_loss: 0.2211 - val_accuracy: 0.8663
# Epoch 71/75
# 12/12 - 2s - loss: 0.0086 - accuracy: 0.9895 - val_loss: 0.2123 - val_accuracy: 0.8696
# Epoch 72/75
# 12/12 - 2s - loss: 0.0071 - accuracy: 0.9916 - val_loss: 0.2111 - val_accuracy: 0.8696
# Epoch 73/75
# 12/12 - 2s - loss: 0.0085 - accuracy: 0.9893 - val_loss: 0.2095 - val_accuracy: 0.8696
# Epoch 74/75
# 12/12 - 2s - loss: 0.0074 - accuracy: 0.9908 - val_loss: 0.2376 - val_accuracy: 0.8533
# Epoch 75/75
# 12/12 - 2s - loss: 0.0071 - accuracy: 0.9907 - val_loss: 0.2304 - val_accuracy: 0.8631
# Iteration:	3
# EMBEDDING:	glove
# STOP_WORDS:	False
# LEMMATIZATION:	False
# HIDDEN_DIM:	32
# HIDDEN_DIM:	128
# LSTM_STACK:	True
# DROP_OUT:	True
# DROP_OUT:	0.1
# SAMPLE_WEIGHTS:	False
# TRAINABLE:	True
#
# Epoch 1/75
# 12/12 - 22s - loss: 0.3125 - accuracy: 0.5787 - val_loss: 0.2578 - val_accuracy: 0.6379
# Epoch 2/75
# 12/12 - 3s - loss: 0.2604 - accuracy: 0.6651 - val_loss: 0.2069 - val_accuracy: 0.7249
# Epoch 3/75
# 12/12 - 3s - loss: 0.2144 - accuracy: 0.7414 - val_loss: 0.1968 - val_accuracy: 0.7404
# Epoch 4/75
# 12/12 - 3s - loss: 0.1892 - accuracy: 0.7758 - val_loss: 0.1766 - val_accuracy: 0.7735
# Epoch 5/75
# 12/12 - 3s - loss: 0.1664 - accuracy: 0.8129 - val_loss: 0.1615 - val_accuracy: 0.8170
# Epoch 6/75
# 12/12 - 3s - loss: 0.1479 - accuracy: 0.8312 - val_loss: 0.1728 - val_accuracy: 0.7975
# Epoch 7/75
# 12/12 - 3s - loss: 0.1332 - accuracy: 0.8474 - val_loss: 0.1420 - val_accuracy: 0.8183
# Epoch 8/75
# 12/12 - 3s - loss: 0.1249 - accuracy: 0.8647 - val_loss: 0.1518 - val_accuracy: 0.8267
# Epoch 9/75
# 12/12 - 3s - loss: 0.1127 - accuracy: 0.8774 - val_loss: 0.1401 - val_accuracy: 0.8378
# Epoch 10/75
# 12/12 - 3s - loss: 0.0105 - accuracy: 0.9890 - val_loss: 0.2112 - val_accuracy: 0.8657
# Epoch 56/75
# 12/12 - 3s - loss: 0.0099 - accuracy: 0.9888 - val_loss: 0.2073 - val_accuracy: 0.8676
# Epoch 57/75
# 12/12 - 3s - loss: 0.0104 - accuracy: 0.9876 - val_loss: 0.2097 - val_accuracy: 0.8702
# Epoch 58/75
# 12/12 - 3s - loss: 0.0108 - accuracy: 0.9869 - val_loss: 0.2177 - val_accuracy: 0.8644
# Epoch 59/75
# 12/12 - 3s - loss: 0.0084 - accuracy: 0.9896 - val_loss: 0.2066 - val_accuracy: 0.8825
# Epoch 60/75
# 12/12 - 3s - loss: 0.0080 - accuracy: 0.9919 - val_loss: 0.2188 - val_accuracy: 0.8754
# Epoch 61/75
# 12/12 - 3s - loss: 0.0092 - accuracy: 0.9905 - val_loss: 0.2083 - val_accuracy: 0.8715
# Epoch 62/75
# 12/12 - 3s - loss: 0.0107 - accuracy: 0.9870 - val_loss: 0.2164 - val_accuracy: 0.8650
# Epoch 63/75
# 12/12 - 3s - loss: 0.0080 - accuracy: 0.9904 - val_loss: 0.2174 - val_accuracy: 0.8754
# Epoch 64/75
# 12/12 - 3s - loss: 0.0066 - accuracy: 0.9925 - val_loss: 0.2263 - val_accuracy: 0.8735
# Epoch 65/75
# 12/12 - 3s - loss: 0.0085 - accuracy: 0.9893 - val_loss: 0.2245 - val_accuracy: 0.8741
# Epoch 66/75
# 12/12 - 3s - loss: 0.0078 - accuracy: 0.9914 - val_loss: 0.2078 - val_accuracy: 0.8787
# Epoch 67/75
# 12/12 - 3s - loss: 0.0073 - accuracy: 0.9914 - val_loss: 0.2450 - val_accuracy: 0.8585
# Epoch 68/75
# 12/12 - 3s - loss: 0.0071 - accuracy: 0.9905 - val_loss: 0.2230 - val_accuracy: 0.8754
# Epoch 69/75
# 12/12 - 3s - loss: 0.0057 - accuracy: 0.9936 - val_loss: 0.2290 - val_accuracy: 0.8793
# Epoch 70/75
# 12/12 - 3s - loss: 0.0086 - accuracy: 0.9885 - val_loss: 0.2303 - val_accuracy: 0.8748
# Epoch 71/75
# 12/12 - 3s - loss: 0.0075 - accuracy: 0.9898 - val_loss: 0.2350 - val_accuracy: 0.8709
# Epoch 72/75
# 12/12 - 3s - loss: 0.0067 - accuracy: 0.9916 - val_loss: 0.2334 - val_accuracy: 0.8735
# Epoch 73/75
# 12/12 - 3s - loss: 0.0074 - accuracy: 0.9910 - val_loss: 0.2186 - val_accuracy: 0.8754
# Epoch 74/75
# 12/12 - 3s - loss: 0.0068 - accuracy: 0.9904 - val_loss: 0.2214 - val_accuracy: 0.8761
# Epoch 75/75
# 12/12 - 3s - loss: 0.0067 - accuracy: 0.9902 - val_loss: 0.2241 - val_accuracy: 0.8735
# Iteration:	4
# EMBEDDING:	glove
# STOP_WORDS:	False
# LEMMATIZATION:	False
# HIDDEN_DIM:	32
# HIDDEN_DIM:	256
# LSTM_STACK:	True
# DROP_OUT:	True
# DROP_OUT:	0.1
# SAMPLE_WEIGHTS:	False
# Epoch 69/75
# 12/12 - 12s - loss: 0.0060 - accuracy: 0.9940 - val_loss: 0.2417 - val_accuracy: 0.8696
# Epoch 70/75
# 12/12 - 13s - loss: 0.0074 - accuracy: 0.9913 - val_loss: 0.2204 - val_accuracy: 0.8689
# Epoch 71/75
# 12/12 - 15s - loss: 0.0067 - accuracy: 0.9907 - val_loss: 0.2381 - val_accuracy: 0.8696
# Epoch 72/75
# 12/12 - 16s - loss: 0.0062 - accuracy: 0.9914 - val_loss: 0.2322 - val_accuracy: 0.8741
# Epoch 73/75
# 12/12 - 14s - loss: 0.0061 - accuracy: 0.9924 - val_loss: 0.2132 - val_accuracy: 0.8748
# Epoch 74/75
# 12/12 - 12s - loss: 0.0073 - accuracy: 0.9917 - val_loss: 0.2629 - val_accuracy: 0.8676
# Epoch 75/75
# 12/12 - 12s - loss: 0.0061 - accuracy: 0.9922 - val_loss: 0.2311 - val_accuracy: 0.8676
# Iteration:	5
# EMBEDDING:	glove
# STOP_WORDS:	False
# LEMMATIZATION:	False
# HIDDEN_DIM:	64
# HIDDEN_DIM:	32
# LSTM_STACK:	True
# DROP_OUT:	True
# DROP_OUT:	0.1
# SAMPLE_WEIGHTS:	False
# TRAINABLE:	True
#
# Epoch 1/75
# 12/12 - 21s - loss: 0.3226 - accuracy: 0.5368 - val_loss: 0.2608 - val_accuracy: 0.6613
# Epoch 2/75
# 12/12 - 2s - loss: 0.2672 - accuracy: 0.6694 - val_loss: 0.2203 - val_accuracy: 0.7119
# Epoch 3/75
# 12/12 - 3s - loss: 0.2291 - accuracy: 0.7241 - val_loss: 0.2190 - val_accuracy: 0.6944
# Epoch 4/75
# 12/12 - 3s - loss: 0.2035 - accuracy: 0.7530 - val_loss: 0.1751 - val_accuracy: 0.7826
# Epoch 5/75
# 12/12 - 3s - loss: 0.1733 - accuracy: 0.8117 - val_loss: 0.1674 - val_accuracy: 0.8014
# Epoch 6/75
# 12/12 - 3s - loss: 0.1563 - accuracy: 0.8267 - val_loss: 0.1623 - val_accuracy: 0.7988
# Epoch 7/75
# 12/12 - 3s - loss: 0.1366 - accuracy: 0.8499 - val_loss: 0.1461 - val_accuracy: 0.8248
# Epoch 8/75
# 12/12 - 2s - loss: 0.1277 - accuracy: 0.8664 - val_loss: 0.1500 - val_accuracy: 0.8274
# Epoch 9/75
# 12/12 - 3s - loss: 0.1170 - accuracy: 0.8757 - val_loss: 0.1364 - val_accuracy: 0.8501
# Epoch 10/75
# 12/12 - 3s - loss: 0.0971 - accuracy: 0.9022 - val_loss: 0.1526 - val_accuracy: 0.8215
# Epoch 11/75
# 12/12 - 3s - loss: 0.1000 - accuracy: 0.8932 - val_loss: 0.1369 - val_accuracy: 0.8456
# Epoch 12/75
# 12/12 - 3s - loss: 0.0900 - accuracy: 0.9037 - val_loss: 0.1301 - val_accuracy: 0.8553
# Epoch 13/75
# 12/12 - 3s - loss: 0.0828 - accuracy: 0.9149 - val_loss: 0.1391 - val_accuracy: 0.8384
# Epoch 14/75
# 12/12 - 3s - loss: 0.0071 - accuracy: 0.9925 - val_loss: 0.2039 - val_accuracy: 0.8728
# Epoch 60/75
# 12/12 - 2s - loss: 0.0084 - accuracy: 0.9910 - val_loss: 0.2060 - val_accuracy: 0.8787
# Epoch 61/75
# 12/12 - 2s - loss: 0.0072 - accuracy: 0.9916 - val_loss: 0.2130 - val_accuracy: 0.8637
# Epoch 62/75
# 12/12 - 2s - loss: 0.0074 - accuracy: 0.9908 - val_loss: 0.2437 - val_accuracy: 0.8507
# Epoch 63/75
# 12/12 - 2s - loss: 0.0070 - accuracy: 0.9907 - val_loss: 0.2233 - val_accuracy: 0.8663
# Epoch 64/75
# 12/12 - 3s - loss: 0.0071 - accuracy: 0.9919 - val_loss: 0.2058 - val_accuracy: 0.8761
# Epoch 65/75
# 12/12 - 2s - loss: 0.0088 - accuracy: 0.9908 - val_loss: 0.2324 - val_accuracy: 0.8598
# Epoch 66/75
# 12/12 - 3s - loss: 0.0066 - accuracy: 0.9911 - val_loss: 0.2095 - val_accuracy: 0.8741
# Epoch 67/75
# 12/12 - 2s - loss: 0.0061 - accuracy: 0.9928 - val_loss: 0.2075 - val_accuracy: 0.8741
# Epoch 68/75
# 12/12 - 2s - loss: 0.0051 - accuracy: 0.9937 - val_loss: 0.2263 - val_accuracy: 0.8715
# Epoch 69/75
# 12/12 - 3s - loss: 0.0079 - accuracy: 0.9914 - val_loss: 0.2202 - val_accuracy: 0.8670
# Epoch 70/75
# 12/12 - 2s - loss: 0.0076 - accuracy: 0.9898 - val_loss: 0.2131 - val_accuracy: 0.8722
# Epoch 71/75
# 12/12 - 2s - loss: 0.0061 - accuracy: 0.9914 - val_loss: 0.2127 - val_accuracy: 0.8761
# Epoch 72/75
# 12/12 - 2s - loss: 0.0062 - accuracy: 0.9917 - val_loss: 0.2166 - val_accuracy: 0.8748
# Epoch 73/75
# 12/12 - 3s - loss: 0.0073 - accuracy: 0.9913 - val_loss: 0.2143 - val_accuracy: 0.8722
# Epoch 74/75
# 12/12 - 3s - loss: 0.0062 - accuracy: 0.9916 - val_loss: 0.2342 - val_accuracy: 0.8611
# Epoch 75/75
# 12/12 - 3s - loss: 0.0066 - accuracy: 0.9907 - val_loss: 0.2200 - val_accuracy: 0.8722
# Iteration:	6
# EMBEDDING:	glove
# STOP_WORDS:	False
# LEMMATIZATION:	False
# HIDDEN_DIM:	64
# HIDDEN_DIM:	64
# LSTM_STACK:	True
# DROP_OUT:	True
# DROP_OUT:	0.1
# SAMPLE_WEIGHTS:	False
# TRAINABLE:	True
#
# Epoch 1/75
# 12/12 - 26s - loss: 0.3207 - accuracy: 0.5582 - val_loss: 0.2610 - val_accuracy: 0.6768
# Epoch 2/75
# 12/12 - 3s - loss: 0.2614 - accuracy: 0.6854 - val_loss: 0.2114 - val_accuracy: 0.7378
# Epoch 3/75
# 12/12 - 3s - loss: 0.2156 - accuracy: 0.7408 - val_loss: 0.1902 - val_accuracy: 0.7359
# Epoch 4/75
# 12/12 - 3s - loss: 0.1950 - accuracy: 0.7759 - val_loss: 0.1708 - val_accuracy: 0.7904
# Epoch 5/75
# 12/12 - 3s - loss: 0.1661 - accuracy: 0.8092 - val_loss: 0.1519 - val_accuracy: 0.8235
# Epoch 6/75
# 12/12 - 3s - loss: 0.1473 - accuracy: 0.8371 - val_loss: 0.1571 - val_accuracy: 0.8131
# Epoch 7/75
# 12/12 - 3s - loss: 0.1279 - accuracy: 0.8600 - val_loss: 0.1370 - val_accuracy: 0.8345
# Epoch 8/75
# 12/12 - 3s - loss: 0.1231 - accuracy: 0.8661 - val_loss: 0.1407 - val_accuracy: 0.8293
# Epoch 9/75
# 12/12 - 3s - loss: 0.1085 - accuracy: 0.8844 - val_loss: 0.1371 - val_accuracy: 0.8378
# Epoch 10/75
# 12/12 - 3s - loss: 0.0936 - accuracy: 0.9031 - val_loss: 0.1385 - val_accuracy: 0.8274
# Epoch 11/75
# 12/12 - 3s - loss: 0.0948 - accuracy: 0.8942 - val_loss: 0.1356 - val_accuracy: 0.8514
# Epoch 12/75
# 12/12 - 3s - loss: 0.0847 - accuracy: 0.9113 - val_loss: 0.1255 - val_accuracy: 0.8559
# Epoch 13/75
# 12/12 - 3s - loss: 0.0714 - accuracy: 0.9301 - val_loss: 0.1338 - val_accuracy: 0.8559
# Epoch 14/75
# 12/12 - 3s - loss: 0.0699 - accuracy: 0.9239 - val_loss: 0.1371 - val_accuracy: 0.8456
# Epoch 15/75
# 12/12 - 3s - loss: 0.0629 - accuracy: 0.9315 - val_loss: 0.1454 - val_accuracy: 0.8514
# Epoch 16/75
# 12/12 - 3s - loss: 0.0610 - accuracy: 0.9334 - val_loss: 0.1599 - val_accuracy: 0.8384
# Epoch 17/75
# 12/12 - 3s - loss: 0.0524 - accuracy: 0.9450 - val_loss: 0.1464 - val_accuracy: 0.8559
# Epoch 18/75
# 12/12 - 3s - loss: 0.0533 - accuracy: 0.9413 - val_loss: 0.1408 - val_accuracy: 0.8546
# Epoch 19/75
# 12/12 - 3s - loss: 0.0484 - accuracy: 0.9489 - val_loss: 0.1542 - val_accuracy: 0.8579
# Epoch 20/75
# 12/12 - 3s - loss: 0.0450 - accuracy: 0.9543 - val_loss: 0.1717 - val_accuracy: 0.8339
# Epoch 21/75
# 12/12 - 3s - loss: 0.0424 - accuracy: 0.9561 - val_loss: 0.1597 - val_accuracy: 0.8501
# Epoch 22/75
# 12/12 - 3s - loss: 0.0390 - accuracy: 0.9596 - val_loss: 0.1683 - val_accuracy: 0.8436
# Epoch 23/75
# 12/12 - 3s - loss: 0.0318 - accuracy: 0.9658 - val_loss: 0.1495 - val_accuracy: 0.8611
# Epoch 24/75
# 12/12 - 3s - loss: 0.0354 - accuracy: 0.9619 - val_loss: 0.1729 - val_accuracy: 0.8449
# Epoch 25/75
# 12/12 - 3s - loss: 0.0316 - accuracy: 0.9659 - val_loss: 0.1549 - val_accuracy: 0.8618
# Epoch 26/75
# 12/12 - 3s - loss: 0.0279 - accuracy: 0.9693 - val_loss: 0.1727 - val_accuracy: 0.8488
# Epoch 27/75
# 12/12 - 3s - loss: 0.0290 - accuracy: 0.9702 - val_loss: 0.1580 - val_accuracy: 0.8650
# Epoch 28/75
# 12/12 - 3s - loss: 0.0246 - accuracy: 0.9734 - val_loss: 0.1696 - val_accuracy: 0.8579
# Epoch 29/75
# 12/12 - 3s - loss: 0.0266 - accuracy: 0.9716 - val_loss: 0.1645 - val_accuracy: 0.8663
# Epoch 30/75
# 12/12 - 3s - loss: 0.0229 - accuracy: 0.9751 - val_loss: 0.1626 - val_accuracy: 0.8605
# Epoch 31/75
# 12/12 - 3s - loss: 0.0209 - accuracy: 0.9792 - val_loss: 0.1714 - val_accuracy: 0.8624
# Epoch 32/75
# 12/12 - 3s - loss: 0.0202 - accuracy: 0.9817 - val_loss: 0.1750 - val_accuracy: 0.8650
# Epoch 33/75
# 12/12 - 3s - loss: 0.0237 - accuracy: 0.9725 - val_loss: 0.1768 - val_accuracy: 0.8585
# Epoch 34/75
# 12/12 - 3s - loss: 0.0178 - accuracy: 0.9798 - val_loss: 0.1874 - val_accuracy: 0.8618
# Epoch 35/75
# 12/12 - 3s - loss: 0.0167 - accuracy: 0.9829 - val_loss: 0.1943 - val_accuracy: 0.8559
# Epoch 36/75
# 12/12 - 3s - loss: 0.0158 - accuracy: 0.9824 - val_loss: 0.1853 - val_accuracy: 0.8631
# Epoch 37/75
# 12/12 - 3s - loss: 0.0179 - accuracy: 0.9789 - val_loss: 0.1844 - val_accuracy: 0.8631
# Epoch 38/75
# 12/12 - 3s - loss: 0.0138 - accuracy: 0.9864 - val_loss: 0.1910 - val_accuracy: 0.8618
# Epoch 39/75
# 12/12 - 3s - loss: 0.0132 - accuracy: 0.9855 - val_loss: 0.2103 - val_accuracy: 0.8527
# Epoch 40/75
# 12/12 - 3s - loss: 0.0143 - accuracy: 0.9844 - val_loss: 0.1955 - val_accuracy: 0.8572
# Epoch 41/75
# 12/12 - 3s - loss: 0.0136 - accuracy: 0.9853 - val_loss: 0.2102 - val_accuracy: 0.8579
# Epoch 42/75
# 12/12 - 3s - loss: 0.0132 - accuracy: 0.9861 - val_loss: 0.1968 - val_accuracy: 0.8611
# Epoch 43/75
# 12/12 - 3s - loss: 0.0124 - accuracy: 0.9865 - val_loss: 0.2006 - val_accuracy: 0.8644
# Epoch 44/75
# 12/12 - 3s - loss: 0.0140 - accuracy: 0.9852 - val_loss: 0.2007 - val_accuracy: 0.8598
# Epoch 45/75
# 12/12 - 3s - loss: 0.0112 - accuracy: 0.9867 - val_loss: 0.2026 - val_accuracy: 0.8624
# Epoch 46/75
# 12/12 - 3s - loss: 0.0104 - accuracy: 0.9872 - val_loss: 0.2038 - val_accuracy: 0.8611
# Epoch 47/75
# 12/12 - 3s - loss: 0.0105 - accuracy: 0.9901 - val_loss: 0.2086 - val_accuracy: 0.8579
# Epoch 48/75
# 12/12 - 3s - loss: 0.0101 - accuracy: 0.9882 - val_loss: 0.2021 - val_accuracy: 0.8605
# Epoch 49/75
# 12/12 - 3s - loss: 0.0101 - accuracy: 0.9895 - val_loss: 0.2140 - val_accuracy: 0.8611
# Epoch 50/75
# 12/12 - 3s - loss: 0.0083 - accuracy: 0.9916 - val_loss: 0.2257 - val_accuracy: 0.8566
# Epoch 51/75
# 12/12 - 3s - loss: 0.0110 - accuracy: 0.9850 - val_loss: 0.2141 - val_accuracy: 0.8585
# Epoch 52/75
# 12/12 - 3s - loss: 0.0091 - accuracy: 0.9893 - val_loss: 0.2247 - val_accuracy: 0.8618
# Epoch 53/75
# 12/12 - 3s - loss: 0.0096 - accuracy: 0.9887 - val_loss: 0.2161 - val_accuracy: 0.8598
# Epoch 54/75
# 12/12 - 3s - loss: 0.0080 - accuracy: 0.9902 - val_loss: 0.2334 - val_accuracy: 0.8566
# Epoch 55/75
# 12/12 - 3s - loss: 0.0088 - accuracy: 0.9895 - val_loss: 0.2273 - val_accuracy: 0.8592
# Epoch 56/75
# 12/12 - 3s - loss: 0.0085 - accuracy: 0.9905 - val_loss: 0.2121 - val_accuracy: 0.8605
# Epoch 57/75
# 12/12 - 3s - loss: 0.0070 - accuracy: 0.9922 - val_loss: 0.2596 - val_accuracy: 0.8540
# Epoch 58/75
# 12/12 - 3s - loss: 0.0101 - accuracy: 0.9890 - val_loss: 0.2237 - val_accuracy: 0.8644
# Epoch 59/75
# 12/12 - 3s - loss: 0.0063 - accuracy: 0.9924 - val_loss: 0.2226 - val_accuracy: 0.8611
# Epoch 60/75
# 12/12 - 3s - loss: 0.0071 - accuracy: 0.9911 - val_loss: 0.2142 - val_accuracy: 0.8689
# Epoch 61/75
# 12/12 - 3s - loss: 0.0071 - accuracy: 0.9907 - val_loss: 0.2249 - val_accuracy: 0.8670
# Epoch 62/75
# 12/12 - 3s - loss: 0.0080 - accuracy: 0.9893 - val_loss: 0.2210 - val_accuracy: 0.8598
# Epoch 63/75
# 12/12 - 3s - loss: 0.0057 - accuracy: 0.9927 - val_loss: 0.2213 - val_accuracy: 0.8644
# Epoch 64/75
# 12/12 - 3s - loss: 0.0061 - accuracy: 0.9919 - val_loss: 0.2406 - val_accuracy: 0.8605
# Epoch 65/75
# 12/12 - 3s - loss: 0.0074 - accuracy: 0.9914 - val_loss: 0.2257 - val_accuracy: 0.8663
# Epoch 66/75
# 12/12 - 3s - loss: 0.0058 - accuracy: 0.9931 - val_loss: 0.2195 - val_accuracy: 0.8676
# Epoch 67/75
# 12/12 - 3s - loss: 0.0067 - accuracy: 0.9911 - val_loss: 0.2427 - val_accuracy: 0.8605
# Epoch 68/75
# 12/12 - 3s - loss: 0.0057 - accuracy: 0.9914 - val_loss: 0.2561 - val_accuracy: 0.8572
# Epoch 69/75
# 12/12 - 3s - loss: 0.0059 - accuracy: 0.9933 - val_loss: 0.2468 - val_accuracy: 0.8611
# Epoch 70/75
# 12/12 - 3s - loss: 0.0075 - accuracy: 0.9895 - val_loss: 0.2558 - val_accuracy: 0.8572
# Epoch 71/75
# 12/12 - 3s - loss: 0.0063 - accuracy: 0.9913 - val_loss: 0.2475 - val_accuracy: 0.8605
# Epoch 72/75
# 12/12 - 3s - loss: 0.0056 - accuracy: 0.9925 - val_loss: 0.2548 - val_accuracy: 0.8624
# Epoch 73/75
# 12/12 - 3s - loss: 0.0059 - accuracy: 0.9917 - val_loss: 0.2262 - val_accuracy: 0.8702
# Epoch 74/75
# 12/12 - 3s - loss: 0.0062 - accuracy: 0.9910 - val_loss: 0.2290 - val_accuracy: 0.8650
# Epoch 75/75
# 12/12 - 3s - loss: 0.0072 - accuracy: 0.9896 - val_loss: 0.2571 - val_accuracy: 0.8540
# Iteration:	7
# EMBEDDING:	glove
# STOP_WORDS:	False
# LEMMATIZATION:	False
# HIDDEN_DIM:	64
# HIDDEN_DIM:	128
# LSTM_STACK:	True
# DROP_OUT:	True
# DROP_OUT:	0.1
# SAMPLE_WEIGHTS:	False
# TRAINABLE:	True
#
# Epoch 1/75
# 12/12 - 27s - loss: 0.3226 - accuracy: 0.5665 - val_loss: 0.2559 - val_accuracy: 0.6827
# Epoch 2/75
# 12/12 - 6s - loss: 0.2589 - accuracy: 0.6865 - val_loss: 0.1994 - val_accuracy: 0.7489
# Epoch 3/75
# 12/12 - 6s - loss: 0.2104 - accuracy: 0.7415 - val_loss: 0.1838 - val_accuracy: 0.7411
# Epoch 4/75
# 12/12 - 6s - loss: 0.1831 - accuracy: 0.7923 - val_loss: 0.1667 - val_accuracy: 0.7859
# Epoch 5/75
# 12/12 - 6s - loss: 0.1574 - accuracy: 0.8265 - val_loss: 0.1492 - val_accuracy: 0.8144
# Epoch 6/75
# 12/12 - 6s - loss: 0.1372 - accuracy: 0.8511 - val_loss: 0.1567 - val_accuracy: 0.8073
# Epoch 7/75
# 12/12 - 6s - loss: 0.1245 - accuracy: 0.8586 - val_loss: 0.1307 - val_accuracy: 0.8365
# Epoch 8/75
# 12/12 - 6s - loss: 0.1192 - accuracy: 0.8637 - val_loss: 0.1316 - val_accuracy: 0.8462
# Epoch 9/75
# 12/12 - 6s - loss: 0.1005 - accuracy: 0.8898 - val_loss: 0.1310 - val_accuracy: 0.8540
# Epoch 10/75
# 12/12 - 5s - loss: 0.0885 - accuracy: 0.9039 - val_loss: 0.1209 - val_accuracy: 0.8572
# Epoch 11/75
# 12/12 - 5s - loss: 0.0844 - accuracy: 0.9080 - val_loss: 0.1334 - val_accuracy: 0.8501
# Epoch 12/75
# 12/12 - 6s - loss: 0.0796 - accuracy: 0.9113 - val_loss: 0.1238 - val_accuracy: 0.8624
# Epoch 13/75
# 12/12 - 6s - loss: 0.0680 - accuracy: 0.9268 - val_loss: 0.1342 - val_accuracy: 0.8449
# Epoch 14/75
# 12/12 - 6s - loss: 0.0662 - accuracy: 0.9291 - val_loss: 0.1245 - val_accuracy: 0.8592
# Epoch 15/75
# 12/12 - 6s - loss: 0.0572 - accuracy: 0.9427 - val_loss: 0.1300 - val_accuracy: 0.8618
# Epoch 16/75
# 12/12 - 6s - loss: 0.0545 - accuracy: 0.9389 - val_loss: 0.1328 - val_accuracy: 0.8533
# Epoch 17/75
# 12/12 - 6s - loss: 0.0492 - accuracy: 0.9473 - val_loss: 0.1396 - val_accuracy: 0.8618
# Epoch 18/75
# 12/12 - 6s - loss: 0.0509 - accuracy: 0.9424 - val_loss: 0.1408 - val_accuracy: 0.8618
# Epoch 19/75
# 12/12 - 6s - loss: 0.0434 - accuracy: 0.9517 - val_loss: 0.1686 - val_accuracy: 0.8514
# Epoch 20/75
# 12/12 - 6s - loss: 0.0418 - accuracy: 0.9546 - val_loss: 0.1401 - val_accuracy: 0.8605
# Epoch 21/75
# 12/12 - 6s - loss: 0.0357 - accuracy: 0.9622 - val_loss: 0.1409 - val_accuracy: 0.8611
# Epoch 22/75
# ...
# Epoch 70/75
# 12/12 - 33s - loss: 0.0138 - accuracy: 0.9853 - val_loss: 0.1518 - val_accuracy: 0.8858
# Epoch 71/75
# 12/12 - 33s - loss: 0.0137 - accuracy: 0.9810 - val_loss: 0.1757 - val_accuracy: 0.8812
# Epoch 72/75
# 12/12 - 32s - loss: 0.0143 - accuracy: 0.9839 - val_loss: 0.1822 - val_accuracy: 0.8715
# Epoch 73/75
# 12/12 - 33s - loss: 0.0100 - accuracy: 0.9888 - val_loss: 0.1842 - val_accuracy: 0.8754
# Epoch 74/75
# 12/12 - 32s - loss: 0.0133 - accuracy: 0.9839 - val_loss: 0.1599 - val_accuracy: 0.8890
# Epoch 75/75
# 12/12 - 33s - loss: 0.0119 - accuracy: 0.9847 - val_loss: 0.1764 - val_accuracy: 0.8812
# Iteration:	47
# EMBEDDING:	glove
# STOP_WORDS:	False
# LEMMATIZATION:	False
# HIDDEN_DIM:	256
# HIDDEN_DIM:	128
# LSTM_STACK:	True
# DROP_OUT:	True
# DROP_OUT:	0.5
# SAMPLE_WEIGHTS:	False
# TRAINABLE:	True
#
# Epoch 1/75
# 12/12 - 66s - loss: 0.3473 - accuracy: 0.5306 - val_loss: 0.2556 - val_accuracy: 0.6671
# Epoch 2/75
# 12/12 - 37s - loss: 0.2726 - accuracy: 0.6611 - val_loss: 0.2012 - val_accuracy: 0.7352
# Epoch 3/75
# 12/12 - 32s - loss: 0.2344 - accuracy: 0.7077 - val_loss: 0.1820 - val_accuracy: 0.7586
# Epoch 4/75
# 12/12 - 36s - loss: 0.2057 - accuracy: 0.7533 - val_loss: 0.1739 - val_accuracy: 0.7878
# Epoch 5/75
# 12/12 - 36s - loss: 0.1818 - accuracy: 0.7887 - val_loss: 0.1489 - val_accuracy: 0.8177
# Epoch 6/75
# 12/12 - 34s - loss: 0.1744 - accuracy: 0.7880 - val_loss: 0.1516 - val_accuracy: 0.8125
# Epoch 7/75
# 12/12 - 32s - loss: 0.1566 - accuracy: 0.8167 - val_loss: 0.1362 - val_accuracy: 0.8391
# Epoch 8/75
# 12/12 - 32s - loss: 0.1475 - accuracy: 0.8219 - val_loss: 0.1561 - val_accuracy: 0.8215
# Epoch 9/75
# 12/12 - 32s - loss: 0.1378 - accuracy: 0.8464 - val_loss: 0.1279 - val_accuracy: 0.8501
# Epoch 10/75
# 12/12 - 34s - loss: 0.1258 - accuracy: 0.8519 - val_loss: 0.1351 - val_accuracy: 0.8384
# Epoch 11/75
# Epoch 57/75
# 12/12 - 30s - loss: 0.0168 - accuracy: 0.9827 - val_loss: 0.1806 - val_accuracy: 0.8780
# Epoch 58/75
# 12/12 - 34s - loss: 0.0158 - accuracy: 0.9810 - val_loss: 0.1786 - val_accuracy: 0.8787
# Epoch 59/75
# 12/12 - 33s - loss: 0.0180 - accuracy: 0.9810 - val_loss: 0.1912 - val_accuracy: 0.8728
# Epoch 60/75
# 12/12 - 38s - loss: 0.0158 - accuracy: 0.9824 - val_loss: 0.1780 - val_accuracy: 0.8787
# Epoch 61/75
# 12/12 - 34s - loss: 0.0141 - accuracy: 0.9824 - val_loss: 0.1780 - val_accuracy: 0.8787
# Epoch 62/75
# 12/12 - 35s - loss: 0.0153 - accuracy: 0.9850 - val_loss: 0.1941 - val_accuracy: 0.8676
# Epoch 63/75
# 12/12 - 31s - loss: 0.0126 - accuracy: 0.9853 - val_loss: 0.2041 - val_accuracy: 0.8683
# Epoch 64/75
# 12/12 - 30s - loss: 0.0122 - accuracy: 0.9847 - val_loss: 0.1969 - val_accuracy: 0.8735
# Epoch 65/75
# 12/12 - 32s - loss: 0.0120 - accuracy: 0.9856 - val_loss: 0.1861 - val_accuracy: 0.8812
# Epoch 66/75
# 12/12 - 33s - loss: 0.0165 - accuracy: 0.9801 - val_loss: 0.1786 - val_accuracy: 0.8845
# Epoch 67/75
# 12/12 - 38s - loss: 0.0121 - accuracy: 0.9852 - val_loss: 0.1902 - val_accuracy: 0.8793
# Epoch 68/75
# 12/12 - 36s - loss: 0.0130 - accuracy: 0.9847 - val_loss: 0.1848 - val_accuracy: 0.8715
# Epoch 69/75
# 12/12 - 30s - loss: 0.0110 - accuracy: 0.9876 - val_loss: 0.2113 - val_accuracy: 0.8735
# Epoch 70/75
# 12/12 - 37s - loss: 0.0131 - accuracy: 0.9865 - val_loss: 0.2077 - val_accuracy: 0.8657
# Epoch 71/75
# 12/12 - 35s - loss: 0.0117 - accuracy: 0.9856 - val_loss: 0.2047 - val_accuracy: 0.8696
# Epoch 72/75
# 12/12 - 32s - loss: 0.0171 - accuracy: 0.9817 - val_loss: 0.1913 - val_accuracy: 0.8683
# Epoch 73/75
# 12/12 - 33s - loss: 0.0092 - accuracy: 0.9884 - val_loss: 0.1947 - val_accuracy: 0.8767
# Epoch 74/75
# 12/12 - 36s - loss: 0.0120 - accuracy: 0.9853 - val_loss: 0.1686 - val_accuracy: 0.8761
# Epoch 75/75
# 12/12 - 37s - loss: 0.0085 - accuracy: 0.9891 - val_loss: 0.2056 - val_accuracy: 0.8761
# Iteration:	48
# EMBEDDING:	glove
# STOP_WORDS:	False
# LEMMATIZATION:	False
# HIDDEN_DIM:	256
# HIDDEN_DIM:	256
# LSTM_STACK:	True
# DROP_OUT:	True
# DROP_OUT:	0.5
# SAMPLE_WEIGHTS:	False
# TRAINABLE:	True
#
# Epoch 1/75
# 12/12 - 77s - loss: 0.3705 - accuracy: 0.5251 - val_loss: 0.2529 - val_accuracy: 0.6639
# Epoch 2/75
# 12/12 - 61s - loss: 0.0140 - accuracy: 0.9827 - val_loss: 0.1766 - val_accuracy: 0.8774
# Epoch 71/75
# 12/12 - 61s - loss: 0.0112 - accuracy: 0.9856 - val_loss: 0.1854 - val_accuracy: 0.8728
# Epoch 72/75
# 12/12 - 63s - loss: 0.0091 - accuracy: 0.9896 - val_loss: 0.1911 - val_accuracy: 0.8761
# Epoch 73/75
# 12/12 - 65s - loss: 0.0090 - accuracy: 0.9888 - val_loss: 0.1977 - val_accuracy: 0.8903
# Epoch 74/75
# 12/12 - 63s - loss: 0.0148 - accuracy: 0.9839 - val_loss: 0.1818 - val_accuracy: 0.8838
# Epoch 75/75
# 12/12 - 62s - loss: 0.0097 - accuracy: 0.9879 - val_loss: 0.2098 - val_accuracy: 0.8793

# %% [markdown]
# ## Output Model Summary

# %%
checkpoint = dct_summary.copy()

# %%
hidden_dim_1 = []
hidden_dim_2 = []

hidden_dim_both = dct_summary["hidden_dim_1"]
for i, val in enumerate(hidden_dim_both):
#     print(i)
    if i%2 == 0:
        hidden_dim_1.append(val)
    else:
         hidden_dim_2.append(val)
#     print()

# %%
len(hidden_dim_1)
len(hidden_dim_2)
# Out:
# 48

# %%
checkpoint['hidden_dim_1'] = hidden_dim_1
checkpoint['hidden_dim_2'] = hidden_dim_2

# %%
# Output Results
# Convert dictionary to dataframe
df_summary = pd.DataFrame(checkpoint)

# Create file path
file_name_text = 'entity_extraction_evaluation_iter_2_'
time_stamp =  time.strftime("%Y%m%d-%H%M%S")
file_extension = ".csv"
file_name = file_name_text + time_stamp + file_extension
path = os.path.join(path_dir_data, subfolder_b, 
                    subfolder_entity, file_name)

# Save table
df_summary.to_csv(path, index=False)

# %% [markdown]
# ## Visuals

# %% [markdown]
# ### Accuracy Charts

# %%
# hist = pd.DataFrame(history.history)

# #plot training and validation accuracy
# f = plt.figure(figsize=(5,5))
# plt.plot(hist["accuracy"], label =' Training Accuracy')
# plt.plot(hist["val_accuracy"], label = 'Validation Accuracy')
# plt.legend(loc="lower right")
# plt.show()

# # Save and output
# file_name = 'enitity_extraction_training_validation_accuracy.png'
# path = os.path.join(path_dir_data, file_name)
# f.savefig(path)
# # f.download(path)

# %% [markdown]
# ### Confusion Matrix

# %%
# # Create confusion matrix
# cm = confusion_matrix(y_test_fl, y_pred_fl)
# df_cm = pd.DataFrame(cm, columns=np.unique(y_test_fl), index = np.unique(y_pred_fl))
# df_cm.index.name = 'Actual'
# df_cm.columns.name = 'Predicted'

# # Visualize
# plt.figure(figsize = (10,7))
# sn.set(font_scale=1.4)#for label size
# sn.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16})# font size

# %% [markdown]
# # Save and Restore Model
# The following section tests saving and restoring the model.

# %% [markdown]
# ## Save

# %%
# # Export Model
# folder_keras_model = 'entity_extraction_w_processing_keras'
# path_keras_model = os.path.join(path_dir_data, folder_keras_model)

# # SavedModel
# model.save(path_keras_model)

# %% [markdown]
# # Restore

# %%
# from tensorflow import keras
# model = keras.models.load_model(path_keras_model)
