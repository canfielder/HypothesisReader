# %% [markdown]
# # Purpose
# The purpose of this notebook is to develop the best model for identify in Cause and Effect nodes within a provided hypothesis statement.
#
# This notebook will execute a grid-search style evaluation of mutliple parameters.

# %% [markdown]
# ## Import

# %% [markdown]
# ### Packages

# %%
# General
import codecs, io, os, re, sys, time
from collections import OrderedDict 
from tqdm import tqdm

# Go# ogle
# from google.colab import files

# Analysis
import numpy as np
import pandas as pd
from sklearn.metrics import \
    accuracy_score, classification_report, confusion_matrix, \
    precision_recall_fscore_support
from sklearn.model_selection import ParameterGrid
from sklearn.utils.class_weight import compute_class_weight

# Visual
# import matplotlib.pyplot as plt
# import seaborn as sn

# Deep Learning
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.layers.experimental.preprocessing import TextVectorization

# %% [markdown]
# ### Custom Functions

# %%
sys.path.append('*')
from source_entity_extraction import *
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\canfi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\canfi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Data
# The training data is imported and the necessary columns are converted to lists.

# %%
#import data
path_dir_data ="./../data/"
subfolder_a = "input"
file_training_data = 'training_data_dir_multiclass.xlsx'
path_training_data = os.path.join(path_dir_data, subfolder_b, file_training_data)
dataset = pd.read_excel(path_training_data,  engine='openpyxl')

#convert into lists
df = pd.DataFrame({
    'text': dataset.sentence, 
    'node1': dataset.node_1, 
    'node2': dataset.node_2
    })

df.dropna(inplace = True)

# %% [markdown]
# ## Randomness
# To better control and compare results of the Entity Extraction model between the environments where the model is trainined (Python) and where it will be implemented (R/Shiny), we will attempt to control any random actions by the process to maintain consistent results.

# %%
random_state = 5590
np.random.seed(random_state)
tf.random.set_seed(random_state)

# %% [markdown]
# # Global Actions
# The following section defines global settings or performs actions that are consistent across the entirety of this notebook.

# %% [markdown]
# ## Variables
# Varaibles that are used across multiple calls should be defined here.

# %%
MAX_LENGTH = 50
MAX_FEATURES = 1000
BATCH_SIZE = 32
EMBEDDING_LABELS = [
    "text_vectorization",
    "glove",
    "fasttext"
]

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# ### Text Processing

# %%
df = process_text(
    df, 
    stopwords = False,
    lemmatize = False
    )

# %% [markdown]
# ### Target Generation
# With the text processing complete we will now create two versions of the target set. The first will have the feature tokens converted into numerical representations for each class: 0, 1, 2. Then we will also create a target set that is a one-hot-encoded representation of the numerical classes.

# %%
df = target_gen_wrapper(
    df, 
    max_length=MAX_LENGTH
    )

# %% [markdown]
# ## Split Data into Training / Test Sets

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(
    df,
    test_size=0.25, 
    random_state = random_state
    )

# %% [markdown]
# Due to the different nature of random actions between R and Python, it is easier to export the test set than to duplciate the train/test split.

# %%
subfolder_b = "output"
subfolder_entity = "entity_extraction"
file_name = 'entity_extraction_test_set.csv'
path = os.path.join(path_dir_data, subfolder_b, 
                    subfolder_entity, file_name)
df_test.to_csv(path, index_label=False)

# %% [markdown]
# # Feature/Target Definition
# We need to define a target variable and perform preprocessing steps on the features before inputting into the model

# %%
# Features
X_train = df_train['text'].tolist()
X_test = df_test['text'].tolist()

# Targets
y_train_val = df_train['target_labels'].tolist()
y_test_val = df_test['target_labels'].tolist()

# %% [markdown]
# ### Export Target Classes
# To simplify eventual work in R, we will generate the our target classes the test dataset and export it.

# %%
# # Export Test Target Values
# # Set File Location
# file_name = 'entity_extraction_test_target_classes_cause_effect.csv'
# path = os.path.join(path_dir_data, subfolder_b, subfolder_entity, file_name)

# # Convert Lists to Dataframe
# df_targets_test = pd.DataFrame(y_test_val)

# # Export Target Values
# df_targets_test.to_csv(path, index=False, header=False)

# %% [markdown]
# # Build Model

# %% [markdown]
# ## Vectorization Layer

# %%
vectorization_layer = TextVectorization(
    max_tokens=MAX_FEATURES,
    output_mode='int',
    output_sequence_length=MAX_LENGTH
    )

vectorization_layer.adapt(X_train)

vocab = vectorization_layer.get_vocabulary()
vocab_len = len(vocab)
print(f"Vocabulary Size: {vocab_len}")
# Out:
# Vocabulary Size: 1000

# %%
# Inspect vocabulary
word_index = dict(zip(vocab, range(len(vocab))))
# word_index

# %%
# # Inspect vectorization output
# m = 5
# test_string = X_train[m]
# print(f"Test String - Raw:\n{test_string}")
# print()
# test_string_vec = vectorization_layer([test_string])
# print(f"Test String - Vectorized:\n{test_string_vec[0]}")

# %% [markdown]
# ## Embedding Layer

# %% [markdown]
# ### Initialize Embedding Dictionary

# %%
dct_embedding_index = {}

# Initialize None for text vectorizaiton
dct_embedding_index["text_vectorization"] = {
    "index": None,
    "dimension": None
}

dct_embedding_matrix = {
    "text_vectorization": None
}

# %% [markdown]
# ### Embedding Matrix

# %% [markdown]
# #### Glove

# %% [markdown]
# ##### Import/Load Embeddings

# %%
embed_label = EMBEDDING_LABELS[1]
embedding_dim = 100

# Define file path
subfolder_embed = "pre_trained"
subfolder_embed_glove = "glove.6B"
file_name = "glove.6B.100d.txt"
path = os.path.join(path_dir_data, subfolder_embed, subfolder_embed_glove, file_name)

print("Preparing embedding index...")
embeddings_index = {}
with open(path, encoding="utf8") as f:
    for line in tqdm(f):
        word, coefs = line.split(maxsplit=1)
        coefs = np.fromstring(coefs, "f", sep=" ")
        embeddings_index[word] = coefs

dct_embedding_index[embed_label] = {
    "index": embeddings_index,
    "dimension": embedding_dim
}
print(f"Found {len(embeddings_index)} word vectors.")
# Out:
# 1543it [00:00, 15277.72it/s]
# Preparing embedding index...
# 400000it [00:17, 22569.55it/s]
# Found 400000 word vectors.

# %% [markdown]
# ##### Create Matrix

# %%
embedding_matrix = gen_embedding_matrix(
    dct_embedding_index = dct_embedding_index,
    embed_label = embed_label, 
    vocabulary_length = vocab_len, 
    word_index = word_index
)

dct_embedding_matrix[embed_label] = embedding_matrix

# %% [markdown]
# #### FastText

# %% [markdown]
# ##### Import/Load Embeddings

# %%
embed_label = EMBEDDING_LABELS[2]
embedding_dim = 300

# Define file path
subfolder_embed = "pre_trained"
subfolder_embed_fasttext = "wiki-news-300d-1M.vec"
file_name = "wiki-news-300d-1M.vec"
path = os.path.join(path_dir_data, subfolder_embed, subfolder_embed_fasttext, file_name)
f = codecs.open(path, encoding='utf-8')

print("Preparing embedding index...")
embeddings_index = {}
for line in tqdm(f):
    values = line.rstrip().rsplit(' ')
    # print(values)
    word = values[0]
    # print(word)
    coefs = np.asarray(values[1:], dtype='float32')
    # print(coefs)
    embeddings_index[word] = coefs
f.close()

dct_embedding_index[embed_label] = {
    "index": embeddings_index,
    "dimension": embedding_dim,
}
print(f'Found {len(embeddings_index)} word vectors.')
# Out:
# 535it [00:00, 5348.02it/s]
# Preparing embedding index...
# 999995it [02:27, 6787.02it/s]
# Found 999995 word vectors.

# %% [markdown]
# ##### Create Matrix

# %%
embedding_matrix = gen_embedding_matrix(
    dct_embedding_index = dct_embedding_index,
    embed_label = embed_label, 
    vocabulary_length = vocab_len, 
    word_index = word_index
)

dct_embedding_matrix[embed_label] = embedding_matrix

# %% [markdown]
# ## Imbalance Class Management
# There is an imbalance in the classes predicted by the model. Roughly 90% of tokens are class 0 (not Cause or Entity node, filler words). The remaining classes (1: Cause, 2: Entity) account for about 5% of the remaining tokens, each.
#
# In order to better predict all classes in the dataset, and not create a model which simply predicts the default class, we need to weight each of these classes differently. Unfortunately, we cannot simply use the **class weights** input for training a Keras model. that is because we are predicting a 3D array as an output, and Keras will not allow the use of **class weights** in such a case.
#
# There is a workaround, as discussed in Keras Github issue 3653. We can use **sample weights**, with the sample weights mode set to *temporal*.
#
# https://github.com/keras-team/keras/issues/3653
#
# To apply sample weights to our model, we needa matrix of sample weights to account for all input values. This matrix will be the same size as the y_train output array (n samples X sample length).

# %% [markdown]
# ### Sample Weights

# %%
# Initialize Sample weight matrix
sample_weight_matrix = np.array(y_train_val).copy()

# Flatten matrix
sample_weight_matrix_fl = flatten_list(sample_weight_matrix)

# Determine number of classes
n_classes = np.unique(sample_weight_matrix_fl).shape[0]

# Determine class weights
class_weights = compute_class_weight(
    "balanced", 
    np.unique(sample_weight_matrix_fl), 
    np.array(sample_weight_matrix_fl)
    )

# Replace class label with class weight
for i in range(0, len(class_weights)):
    sample_weight_matrix = np.where(
            sample_weight_matrix==i, 
            class_weights[i], 
            sample_weight_matrix
            )
# Out:
# D:\anaconda3\envs\py-CausalityExtraction_36\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass classes=[0 1 2], y=[0 0 0 ... 0 0 0] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)

# %% [markdown]
# ## Compile Model Architecture

# %%
# # Select embedding label
# embedding_label = EMBEDDING_LABELS[2]
# sample_weights = True

# # Generate embedding layer
# embedding_layer = gen_embedding_layer(
#     label = embedding_label,
#     input_dimension = vocab_len,
#     output_dimension_wo_init = 64,
#     max_length = MAX_LENGTH,
#     embedding_matrix = dct_embedding_matrix[embedding_label]
#     )

# model = compile_model(
#     vectorization_layer = vectorization_layer,
#     embedding_layer = embedding_layer,
#     dropout=False,
#     stack=False,
#     hidden_dimension=128,
#     sample_weights=sample_weights
#  )
# model.summary()

# %%
# # Convert features to numpy array from model input
# X_train = np.array(X_train)

# # Encode targets
# y_train = encode_target(y_train_val)

# # Convert target to numpy array for model input
# y_train = np.array(y_train)

# %%
# # Train model
# if sample_weights: 
#     history = model.fit(
#                         X_train, y_train, 
#                         batch_size=BATCH_SIZE, 
#                         epochs=75, 
#                         validation_split=0.2, 
#                         sample_weight=sample_weight_matrix,
#                         verbose=1
#                         )
# else: 
#     history = model.fit(
#                         X_train, y_train, 
#                         batch_size=BATCH_SIZE, 
#                         epochs=75, 
#                         validation_split=0.2, 
#                         verbose=1
#                         )

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Initialize Output Dictionary

# %%
# dct_summary = OrderedDict()

# dct_summary["embedding"] = []
# dct_summary["stop_words"] = []
# dct_summary["lemmatization"] = []
# dct_summary["hidden_dim"] = []
# dct_summary["lstm_stack"] = []
# dct_summary["dropout"] = []
# dct_summary["sample_weights"] = []
# dct_summary["accuracy"] = []
# dct_summary["precision_0"] = []
# dct_summary["precision_1"] = []
# dct_summary["precision_2"] = []
# dct_summary["precision_macro"] = []
# dct_summary["recall_0"] = []
# dct_summary["recall_1"] = []
# dct_summary["recall_2"] = []
# dct_summary["recall_macro"] = []
# dct_summary["f1_0"] = []
# dct_summary["f1_1"] = []
# dct_summary["f1_2"] = []
# dct_summary["f1_macro"] = []

# %% [markdown]
# ## Generate Predictions

# %%
# # Generate predicted classes
# y_pred = []
# for i in range(len(X_test)):
#     y_pred_prob = model.predict(np.array([X_test[i]]))
#     y_pred_class = np.argmax(y_pred_prob, axis=-1)[0].tolist()
#     y_pred.append(y_pred_class)

# # Flatten lists
# y_pred = flatten_list(y_pred)
# y_test = flatten_list(y_test_val)

# %% [markdown]
# ## Classification Report

# %%
# print(classification_report(y_test, y_pred))

# %% [markdown]
# ## Evaluation Metrics

# %%
# dct_summary = gen_eval_metrics(
#     dct_summary,
#     y_test, y_pred,
#     embedding = embedding_label,
#     stop_words = True,
#     lemmatization = True,
#     hidden_dim = 128,
#     lstm_stack = True,
#     dropout = True,
#     sample_weights = True
#     )

# df_eval = pd.DataFrame(dct_summary)

# %% [markdown]
# ## Save Results

# %%
# # Create file path
# subfolder_entity = "entity_extraction"
# file_name_text = 'entity_extraction_evaluation_'
# time_stamp =  time.strftime("%Y%m%d-%H%M%S")
# file_extension = ".csv"
# file_name = file_name_text + time_stamp + file_extension
# path = os.path.join(path_dir_data, subfolder_b, subfolder_entity, file_name)

# # Save table
# df_eval.to_csv(path, index=False)

# %% [markdown]
# # Grid

# %% [markdown]
# ## Define Parameter Grid

# %%
params = {
    'embedding': ['text_vectorization', 'glove', 'fasttext'],
    'stop_words': [False],
    'lemmatization': [True, False],
    'hidden_dim': [32, 64, 128],
    'lstm_stack': [True, False],
    'dropout': [True, False],
    'sample_weights': [True, False],
    'trainable':  [True, False],

    }
param_grid = list(ParameterGrid(params))
print(f"Number of Parameter Configurations: {len(param_grid)}")
# Out:
# Number of Parameter Configurations: 288

# %% [markdown]
# ## Initialize Output Dictionary

# %%
# Initialize
dct_summary = OrderedDict()

dct_summary["embedding"] = []
dct_summary["stop_words"] = []
dct_summary["lemmatization"] = []
dct_summary["hidden_dim"] = []
dct_summary["lstm_stack"] = []
dct_summary["dropout"] = []
dct_summary["sample_weights"] = []
dct_summary["trainable"] = []
dct_summary["accuracy"] = []
dct_summary["precision_0"] = []
dct_summary["precision_1"] = []
dct_summary["precision_2"] = []
dct_summary["precision_macro"] = []
dct_summary["recall_0"] = []
dct_summary["recall_1"] = []
dct_summary["recall_2"] = []
dct_summary["recall_macro"] = []
dct_summary["f1_0"] = []
dct_summary["f1_1"] = []
dct_summary["f1_2"] = []
dct_summary["f1_macro"] = []

# %% [markdown]
# ## Execute Model Training/Evaluation

# %%
for i, param in enumerate(param_grid):

    # Define Parameters
    EMBEDDING = param['embedding']
    STOP_WORDS = param['stop_words']
    LEMMATIZATION = param['lemmatization']
    HIDDEN_DIM = param['hidden_dim']
    LSTM_STACK = param['lstm_stack']
    DROP_OUT = param['dropout']
    SAMPLE_WEIGHTS = param['sample_weights']
    TRAINABLE = param['trainable']

    print(f"Iteration:\t{i + 1}")
    print(f"EMBEDDING:\t{EMBEDDING}")
    print(f"STOP_WORDS:\t{STOP_WORDS}")
    print(f"LEMMATIZATION:\t{LEMMATIZATION}")
    print(f"HIDDEN_DIM:\t{HIDDEN_DIM}")
    print(f"LSTM_STACK:\t{LSTM_STACK}")
    print(f"DROP_OUT:\t{DROP_OUT}")
    print(f"SAMPLE_WEIGHTS:\t{SAMPLE_WEIGHTS}")
    print(f"TRAINABLE:\t{TRAINABLE}")
    print()

    # Initialize input dataframe
    df_iter = df.copy()

    # Process ------------------------------------------------------------------
    # Process Text
    df_iter = process_text(
        df_iter, 
        stopwords = STOP_WORDS,
        lemmatize = LEMMATIZATION
    )

    # Generate Target Labels
    df_iter = target_gen_wrapper(
        df_iter, 
        max_length=MAX_LENGTH
        )
    
    # Split Training/Test Set
    df_train, df_test = train_test_split(
        df_iter,
        test_size=0.25, 
        random_state = random_state
        )
    
    # Define Target/Features
    # Features
    X_train = df_train['text'].tolist()
    X_test = df_test['text'].tolist()

    # Target
    y_train_val = df_train['target_labels'].tolist()
    y_test_val = df_test['target_labels'].tolist()

    # Build Model --------------------------------------------------------------
    # Vectorization Layer
    vectorization_layer = TextVectorization(
        max_tokens=MAX_FEATURES,
        output_mode='int',
        output_sequence_length=MAX_LENGTH
        )

    # Adapt to training data
    vectorization_layer.adapt(X_train)

    # Define vocabulary
    vocab = vectorization_layer.get_vocabulary()
    vocab_len = len(vocab)
    word_index = dict(zip(vocab, range(vocab_len)))

    # Create embedding matrix
    embedding_matrix = gen_embedding_matrix(
        dct_embedding_index = dct_embedding_index,
        embed_label = EMBEDDING, 
        vocabulary_length = vocab_len, 
        word_index = word_index
        )

    # Embedding Layer
    embedding_layer = gen_embedding_layer(
        label = EMBEDDING,
        input_dimension = vocab_len,
        output_dimension_wo_init = 64,
        max_length = MAX_LENGTH,
        embedding_matrix = embedding_matrix,
        trainable = TRAINABLE
        )

    # Compile Model
    model = compile_model(
        vectorization_layer = vectorization_layer,
        embedding_layer = embedding_layer,
        dropout = DROP_OUT,
        stack = LSTM_STACK,
        hidden_dimension = HIDDEN_DIM,
        sample_weights = SAMPLE_WEIGHTS
    )

    # Convert and encode target/features
    # # Convert features to numpy array from model input
    X_train = np.array(X_train)

    # Encode targets
    y_train = encode_target(y_train_val)

    # Convert target to numpy array for model input
    y_train = np.array(y_train)

    # Train Model --------------------------------------------------------------
    if SAMPLE_WEIGHTS: 
        history = model.fit(
                            X_train, y_train, 
                            batch_size=BATCH_SIZE, 
                            epochs=75, 
                            validation_split=0.2, 
                            sample_weight=sample_weight_matrix,
                            verbose=1
                            )
    else: 
        history = model.fit(
                            X_train, y_train, 
                            batch_size=BATCH_SIZE, 
                            epochs=75, 
                            validation_split=0.2, 
                            verbose=1
                            )
        
    # Evaluation ---------------------------------------------------------------
    # Generate Predictions
    y_pred = []
    for i in range(len(X_test)):
        y_pred_prob = model.predict(np.array([X_test[i]]))
        y_pred_class = np.argmax(y_pred_prob, axis=-1)[0].tolist()
        y_pred.append(y_pred_class)

    # Flatten lists
    y_pred = flatten_list(y_pred)
    y_test = flatten_list(y_test_val)

    # Score Model
    dct_summary = gen_eval_metrics(
        dct_summary,
        y_test, y_pred,
        embedding = EMBEDDING,
        stop_words = STOP_WORDS,
        lemmatization = LEMMATIZATION,
        hidden_dim = HIDDEN_DIM,
        lstm_stack = LSTM_STACK,
        dropout = DROP_OUT,
        sample_weights = SAMPLE_WEIGHTS,
        trainable = TRAINABLE
        )
# Out:
# Iteration:	1
# EMBEDDING:	text_vectorization
# STOP_WORDS:	False
# LEMMATIZATION:	True
# HIDDEN_DIM:	32
# LSTM_STACK:	True
# DROP_OUT:	True
# SAMPLE_WEIGHTS:	True
# TRAINABLE:	True
#
# Epoch 1/75
# 12/12 [==============================] - 14s 311ms/step - loss: 0.7733 - accuracy: 0.3340 - val_loss: 0.5542 - val_accuracy: 0.3699
# Epoch 2/75
# 12/12 [==============================] - 2s 131ms/step - loss: 0.5727 - accuracy: 0.3621 - val_loss: 0.4570 - val_accuracy: 0.3855
# Epoch 3/75
# 12/12 [==============================] - 2s 131ms/step - loss: 0.5022 - accuracy: 0.3829 - val_loss: 0.3998 - val_accuracy: 0.3945
# Epoch 4/75
# 12/12 [==============================] - 2s 131ms/step - loss: 0.3918 - accuracy: 0.4081 - val_loss: 0.3682 - val_accuracy: 0.4056
# Epoch 5/75
# 12/12 [==============================] - 2s 128ms/step - loss: 0.3264 - accuracy: 0.4540 - val_loss: 0.3469 - val_accuracy: 0.4270
# Epoch 6/75
# 12/12 [==============================] - 2s 132ms/step - loss: 0.3083 - accuracy: 0.4574 - val_loss: 0.3509 - val_accuracy: 0.4400
# Epoch 7/75
# 12/12 [==============================] - 2s 140ms/step - loss: 0.2747 - accuracy: 0.4862 - val_loss: 0.3664 - val_accuracy: 0.4296
# Epoch 8/75
# 12/12 [==============================] - 2s 137ms/step - loss: 0.2788 - accuracy: 0.4631 - val_loss: 0.3285 - val_accuracy: 0.4530
# Epoch 9/75
# 12/12 [==============================] - 2s 132ms/step - loss: 0.2471 - accuracy: 0.4883 - val_loss: 0.3440 - val_accuracy: 0.4432
# Epoch 10/75
# 12/12 [==============================] - 2s 127ms/step - loss: 0.2326 - accuracy: 0.5025 - val_loss: 0.3538 - val_accuracy: 0.4633
# Epoch 11/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.2211 - accuracy: 0.5213 - val_loss: 0.3517 - val_accuracy: 0.4880
# Epoch 12/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.2170 - accuracy: 0.5220 - val_loss: 0.3318 - val_accuracy: 0.5016
# Epoch 13/75
# 12/12 [==============================] - 2s 128ms/step - loss: 0.2034 - accuracy: 0.5654 - val_loss: 0.3413 - val_accuracy: 0.5295
# Epoch 14/75
# 12/12 [==============================] - 2s 132ms/step - loss: 0.1887 - accuracy: 0.5804 - val_loss: 0.3596 - val_accuracy: 0.5432
# Epoch 15/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.1782 - accuracy: 0.6011 - val_loss: 0.3605 - val_accuracy: 0.5425
# Epoch 16/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.1809 - accuracy: 0.6060 - val_loss: 0.3591 - val_accuracy: 0.5256
# Epoch 17/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.1649 - accuracy: 0.6285 - val_loss: 0.3610 - val_accuracy: 0.5613
# Epoch 18/75
# 12/12 [==============================] - ETA: 0s - loss: 0.1607 - accuracy: 0.65 - 2s 135ms/step - loss: 0.1609 - accuracy: 0.6521 - val_loss: 0.3736 - val_accuracy: 0.5847
# Epoch 19/75
# 12/12 [==============================] - 2s 139ms/step - loss: 0.1651 - accuracy: 0.6562 - val_loss: 0.3834 - val_accuracy: 0.5860
# Epoch 20/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.1558 - accuracy: 0.6666 - val_loss: 0.3741 - val_accuracy: 0.6022
# Epoch 21/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.1508 - accuracy: 0.6840 - val_loss: 0.4086 - val_accuracy: 0.6074
# Epoch 22/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.1482 - accuracy: 0.6820 - val_loss: 0.3973 - val_accuracy: 0.6191
# Epoch 23/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.1496 - accuracy: 0.7014 - val_loss: 0.4026 - val_accuracy: 0.6042
# Epoch 24/75
# 12/12 [==============================] - 2s 132ms/step - loss: 0.1459 - accuracy: 0.7062 - val_loss: 0.4114 - val_accuracy: 0.6360
# Epoch 25/75
# 12/12 [==============================] - 2s 127ms/step - loss: 0.1284 - accuracy: 0.7345 - val_loss: 0.4150 - val_accuracy: 0.6217
# Epoch 26/75
# 12/12 [==============================] - 2s 134ms/step - loss: 0.1361 - accuracy: 0.7286 - val_loss: 0.4198 - val_accuracy: 0.6385
# Epoch 27/75
# 12/12 [==============================] - 2s 132ms/step - loss: 0.1300 - accuracy: 0.7381 - val_loss: 0.4104 - val_accuracy: 0.6334
# Epoch 28/75
# 12/12 [==============================] - 2s 137ms/step - loss: 0.1260 - accuracy: 0.7378 - val_loss: 0.4386 - val_accuracy: 0.6249
# Epoch 29/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.1204 - accuracy: 0.7467 - val_loss: 0.4209 - val_accuracy: 0.6515
# Epoch 30/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.1089 - accuracy: 0.7705 - val_loss: 0.4336 - val_accuracy: 0.6600
# Epoch 31/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.1195 - accuracy: 0.7611 - val_loss: 0.4394 - val_accuracy: 0.6775
# Epoch 32/75
# 12/12 [==============================] - 2s 127ms/step - loss: 0.1135 - accuracy: 0.7683 - val_loss: 0.4141 - val_accuracy: 0.6703
# Epoch 33/75
# 12/12 [==============================] - 2s 131ms/step - loss: 0.1037 - accuracy: 0.7873 - val_loss: 0.4198 - val_accuracy: 0.6639
# Epoch 34/75
# 12/12 [==============================] - 2s 128ms/step - loss: 0.0945 - accuracy: 0.7993 - val_loss: 0.4432 - val_accuracy: 0.6632
# Epoch 35/75
# 12/12 [==============================] - 2s 132ms/step - loss: 0.1100 - accuracy: 0.7726 - val_loss: 0.4229 - val_accuracy: 0.6982
# Epoch 36/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.0974 - accuracy: 0.8033 - val_loss: 0.4268 - val_accuracy: 0.6879
# Epoch 37/75
# 12/12 [==============================] - 2s 128ms/step - loss: 0.0893 - accuracy: 0.8122 - val_loss: 0.4166 - val_accuracy: 0.6982
# Epoch 38/75
# 12/12 [==============================] - 2s 141ms/step - loss: 0.0949 - accuracy: 0.8082 - val_loss: 0.4237 - val_accuracy: 0.6755
# Epoch 39/75
# 12/12 [==============================] - 2s 133ms/step - loss: 0.0927 - accuracy: 0.8042 - val_loss: 0.4471 - val_accuracy: 0.7287
# Epoch 40/75
# 12/12 [==============================] - 2s 132ms/step - loss: 0.0899 - accuracy: 0.8303 - val_loss: 0.4150 - val_accuracy: 0.6905
# Epoch 41/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.0843 - accuracy: 0.8209 - val_loss: 0.4433 - val_accuracy: 0.7112
# Epoch 42/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.0881 - accuracy: 0.8319 - val_loss: 0.4493 - val_accuracy: 0.7132
# Epoch 43/75
# 12/12 [==============================] - 2s 128ms/step - loss: 0.0775 - accuracy: 0.8417 - val_loss: 0.4781 - val_accuracy: 0.7398
# Epoch 44/75
# 12/12 [==============================] - 2s 132ms/step - loss: 0.0792 - accuracy: 0.8443 - val_loss: 0.4715 - val_accuracy: 0.7313
# Epoch 45/75
# 12/12 [==============================] - 2s 131ms/step - loss: 0.0732 - accuracy: 0.8475 - val_loss: 0.4749 - val_accuracy: 0.7274
# Epoch 46/75
# 12/12 [==============================] - 2s 134ms/step - loss: 0.0835 - accuracy: 0.8343 - val_loss: 0.4728 - val_accuracy: 0.7502
# Epoch 47/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.0717 - accuracy: 0.8566 - val_loss: 0.4840 - val_accuracy: 0.7534
# Epoch 48/75
# 12/12 [==============================] - 2s 133ms/step - loss: 0.0724 - accuracy: 0.8559 - val_loss: 0.4840 - val_accuracy: 0.7437
# Epoch 49/75
# 12/12 [==============================] - 2s 136ms/step - loss: 0.0626 - accuracy: 0.8692 - val_loss: 0.4852 - val_accuracy: 0.7605
# Epoch 50/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.0682 - accuracy: 0.8691 - val_loss: 0.4727 - val_accuracy: 0.7482
# Epoch 51/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.0693 - accuracy: 0.8704 - val_loss: 0.4970 - val_accuracy: 0.7515
# Epoch 52/75
# 12/12 [==============================] - 2s 131ms/step - loss: 0.0712 - accuracy: 0.8641 - val_loss: 0.5058 - val_accuracy: 0.7541
# Epoch 53/75
# 12/12 [==============================] - 2s 128ms/step - loss: 0.0612 - accuracy: 0.8785 - val_loss: 0.4952 - val_accuracy: 0.7800
# Epoch 54/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.0642 - accuracy: 0.8808 - val_loss: 0.4872 - val_accuracy: 0.7657
# Epoch 55/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.0574 - accuracy: 0.8850 - val_loss: 0.4928 - val_accuracy: 0.7560
# Epoch 56/75
# 12/12 [==============================] - 2s 131ms/step - loss: 0.0543 - accuracy: 0.8923 - val_loss: 0.5227 - val_accuracy: 0.7631
# Epoch 57/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.0554 - accuracy: 0.8945 - val_loss: 0.5252 - val_accuracy: 0.7664
# Epoch 58/75
# 12/12 [==============================] - 2s 139ms/step - loss: 0.0524 - accuracy: 0.8944 - val_loss: 0.5283 - val_accuracy: 0.7547
# Epoch 59/75
# 12/12 [==============================] - 2s 151ms/step - loss: 0.0516 - accuracy: 0.8994 - val_loss: 0.5202 - val_accuracy: 0.7794
# Epoch 60/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.0541 - accuracy: 0.8875 - val_loss: 0.5317 - val_accuracy: 0.7768
# Epoch 61/75
# 12/12 [==============================] - 2s 132ms/step - loss: 0.0553 - accuracy: 0.9003 - val_loss: 0.5103 - val_accuracy: 0.7592
# Epoch 62/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.0521 - accuracy: 0.8997 - val_loss: 0.5017 - val_accuracy: 0.7677
# Epoch 63/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.0496 - accuracy: 0.9012 - val_loss: 0.5190 - val_accuracy: 0.7956
# Epoch 64/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.0481 - accuracy: 0.9078 - val_loss: 0.5785 - val_accuracy: 0.7781
# Epoch 65/75
# 12/12 [==============================] - 2s 131ms/step - loss: 0.0459 - accuracy: 0.9058 - val_loss: 0.5463 - val_accuracy: 0.7826
# Epoch 66/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.0456 - accuracy: 0.9038 - val_loss: 0.5156 - val_accuracy: 0.7567
# Epoch 67/75
# 12/12 [==============================] - 2s 137ms/step - loss: 0.0475 - accuracy: 0.9006 - val_loss: 0.5461 - val_accuracy: 0.7878
# Epoch 68/75
# 12/12 [==============================] - 2s 133ms/step - loss: 0.0436 - accuracy: 0.9187 - val_loss: 0.5523 - val_accuracy: 0.7962
# Epoch 69/75
# 12/12 [==============================] - 2s 139ms/step - loss: 0.0409 - accuracy: 0.9249 - val_loss: 0.5549 - val_accuracy: 0.7541
# Epoch 70/75
# 12/12 [==============================] - 2s 134ms/step - loss: 0.0443 - accuracy: 0.9081 - val_loss: 0.5571 - val_accuracy: 0.7982
# Epoch 71/75
# 12/12 [==============================] - 2s 132ms/step - loss: 0.0434 - accuracy: 0.9232 - val_loss: 0.5942 - val_accuracy: 0.8053
# Epoch 72/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.0428 - accuracy: 0.9204 - val_loss: 0.5555 - val_accuracy: 0.8144
# Epoch 73/75
# 12/12 [==============================] - 2s 131ms/step - loss: 0.0397 - accuracy: 0.9292 - val_loss: 0.5295 - val_accuracy: 0.7975
# Epoch 74/75
# 12/12 [==============================] - 2s 131ms/step - loss: 0.0354 - accuracy: 0.9244 - val_loss: 0.5855 - val_accuracy: 0.8053
# Epoch 75/75
# 12/12 [==============================] - 2s 128ms/step - loss: 0.0344 - accuracy: 0.9325 - val_loss: 0.5597 - val_accuracy: 0.8053
# Iteration:	2
# EMBEDDING:	text_vectorization
# STOP_WORDS:	False
# LEMMATIZATION:	True
# HIDDEN_DIM:	32
# LSTM_STACK:	True
# DROP_OUT:	True
# SAMPLE_WEIGHTS:	True
# TRAINABLE:	False
#
# Epoch 1/75
# 12/12 [==============================] - 12s 249ms/step - loss: 0.7704 - accuracy: 0.3144 - val_loss: 0.5391 - val_accuracy: 0.3699
# Epoch 2/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.5670 - accuracy: 0.3605 - val_loss: 0.4656 - val_accuracy: 0.3829
# Epoch 3/75
# 12/12 [==============================] - 1s 125ms/step - loss: 0.5097 - accuracy: 0.3841 - val_loss: 0.4178 - val_accuracy: 0.3958
# Epoch 4/75
# 12/12 [==============================] - 2s 128ms/step - loss: 0.4020 - accuracy: 0.4012 - val_loss: 0.3787 - val_accuracy: 0.4108
# Epoch 5/75
# 12/12 [==============================] - 2s 127ms/step - loss: 0.3259 - accuracy: 0.4534 - val_loss: 0.3601 - val_accuracy: 0.4257
# Epoch 6/75
# 12/12 [==============================] - 2s 128ms/step - loss: 0.3052 - accuracy: 0.4526 - val_loss: 0.3778 - val_accuracy: 0.4270
# Epoch 7/75
# 12/12 [==============================] - 2s 129ms/step - loss: 0.2698 - accuracy: 0.4916 - val_loss: 0.3718 - val_accuracy: 0.4231
# Epoch 8/75
# 12/12 [==============================] - 2s 133ms/step - loss: 0.2744 - accuracy: 0.4719 - val_loss: 0.3568 - val_accuracy: 0.4374
# Epoch 9/75
# 12/12 [==============================] - 2s 127ms/step - loss: 0.2396 - accuracy: 0.4948 - val_loss: 0.3567 - val_accuracy: 0.4458
# Epoch 10/75
# 12/12 [==============================] - 2s 133ms/step - loss: 0.2277 - accuracy: 0.5034 - val_loss: 0.3718 - val_accuracy: 0.4588
# Epoch 11/75
# 12/12 [==============================] - 2s 161ms/step - loss: 0.2211 - accuracy: 0.5263 - val_loss: 0.3547 - val_accuracy: 0.4899
# Epoch 12/75
# 12/12 [==============================] - 2s 133ms/step - loss: 0.2115 - accuracy: 0.5398 - val_loss: 0.3510 - val_accuracy: 0.4899
# Epoch 13/75
# 12/12 [==============================] - 2s 128ms/step - loss: 0.2068 - accuracy: 0.5574 - val_loss: 0.3652 - val_accuracy: 0.5289
# Epoch 14/75
# 12/12 [==============================] - 2s 141ms/step - loss: 0.1847 - accuracy: 0.5976 - val_loss: 0.3479 - val_accuracy: 0.5211
# Epoch 15/75
# 12/12 [==============================] - 2s 149ms/step - loss: 0.1838 - accuracy: 0.5961 - val_loss: 0.3631 - val_accuracy: 0.5438
# Epoch 16/75
# 12/12 [==============================] - 2s 161ms/step - loss: 0.1813 - accuracy: 0.5974 - val_loss: 0.3656 - val_accuracy: 0.5178
# Epoch 17/75
# 12/12 [==============================] - 2s 146ms/step - loss: 0.1806 - accuracy: 0.6088 - val_loss: 0.3437 - val_accuracy: 0.5380
# Epoch 18/75
# 12/12 [==============================] - 2s 133ms/step - loss: 0.1755 - accuracy: 0.6333 - val_loss: 0.3693 - val_accuracy: 0.5730
# Epoch 19/75
# 12/12 [==============================] - 2s 140ms/step - loss: 0.1761 - accuracy: 0.6455 - val_loss: 0.3879 - val_accuracy: 0.5775
# Epoch 20/75
# 12/12 [==============================] - 2s 156ms/step - loss: 0.1598 - accuracy: 0.6650 - val_loss: 0.3958 - val_accuracy: 0.5561
# Epoch 21/75
# 12/12 [==============================] - 2s 135ms/step - loss: 0.1528 - accuracy: 0.6759 - val_loss: 0.3944 - val_accuracy: 0.5834
# Epoch 22/75
# 12/12 [==============================] - 2s 140ms/step - loss: 0.1514 - accuracy: 0.6753 - val_loss: 0.3875 - val_accuracy: 0.5847
# Epoch 23/75
# 12/12 [==============================] - 2s 138ms/step - loss: 0.1552 - accuracy: 0.6856 - val_loss: 0.3911 - val_accuracy: 0.6035
# Epoch 24/75
# 12/12 [==============================] - 2s 136ms/step - loss: 0.1497 - accuracy: 0.7062 - val_loss: 0.3870 - val_accuracy: 0.6152
# Epoch 25/75
# 12/12 [==============================] - 2s 137ms/step - loss: 0.1336 - accuracy: 0.7279 - val_loss: 0.4135 - val_accuracy: 0.6100
# Epoch 26/75
# 12/12 [==============================] - 2s 138ms/step - loss: 0.1350 - accuracy: 0.7235 - val_loss: 0.4398 - val_accuracy: 0.6269
# Epoch 27/75
# 12/12 [==============================] - 2s 138ms/step - loss: 0.1325 - accuracy: 0.7369 - val_loss: 0.4263 - val_accuracy: 0.6314
# Epoch 28/75
# 12/12 [==============================] - 2s 140ms/step - loss: 0.1258 - accuracy: 0.7419 - val_loss: 0.3803 - val_accuracy: 0.6243
# Epoch 29/75
# 12/12 [==============================] - 2s 147ms/step - loss: 0.1228 - accuracy: 0.7375 - val_loss: 0.3913 - val_accuracy: 0.6626
# Epoch 30/75
# 12/12 [==============================] - 2s 144ms/step - loss: 0.1109 - accuracy: 0.7754 - val_loss: 0.4348 - val_accuracy: 0.6489
# Epoch 31/75
# 12/12 [==============================] - 2s 135ms/step - loss: 0.1099 - accuracy: 0.7754 - val_loss: 0.4284 - val_accuracy: 0.6606
# Epoch 32/75
# 12/12 [==============================] - 2s 179ms/step - loss: 0.1102 - accuracy: 0.7720 - val_loss: 0.4071 - val_accuracy: 0.6619
# Epoch 33/75
# 12/12 [==============================] - 2s 142ms/step - loss: 0.1056 - accuracy: 0.7845 - val_loss: 0.4439 - val_accuracy: 0.6327
# Epoch 34/75
# 12/12 [==============================] - 2s 160ms/step - loss: 0.1035 - accuracy: 0.7824 - val_loss: 0.4064 - val_accuracy: 0.6710
# Epoch 35/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.1088 - accuracy: 0.7753 - val_loss: 0.4125 - val_accuracy: 0.6632
# Epoch 36/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0985 - accuracy: 0.7945 - val_loss: 0.4246 - val_accuracy: 0.6742
# Epoch 37/75
# 12/12 [==============================] - 2s 161ms/step - loss: 0.0879 - accuracy: 0.8099 - val_loss: 0.4260 - val_accuracy: 0.6762
# Epoch 38/75
# 12/12 [==============================] - 2s 188ms/step - loss: 0.0961 - accuracy: 0.7954 - val_loss: 0.4412 - val_accuracy: 0.6677
# Epoch 39/75
# 12/12 [==============================] - 2s 175ms/step - loss: 0.0922 - accuracy: 0.8127 - val_loss: 0.4140 - val_accuracy: 0.6931
# Epoch 40/75
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0855 - accuracy: 0.8283 - val_loss: 0.4312 - val_accuracy: 0.7054
# Epoch 41/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0819 - accuracy: 0.8357 - val_loss: 0.4201 - val_accuracy: 0.6976
# Epoch 42/75
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0825 - accuracy: 0.8436 - val_loss: 0.4546 - val_accuracy: 0.7125
# Epoch 43/75
# 12/12 [==============================] - 2s 175ms/step - loss: 0.0743 - accuracy: 0.8538 - val_loss: 0.4549 - val_accuracy: 0.7171
# Epoch 44/75
# 12/12 [==============================] - 2s 197ms/step - loss: 0.0815 - accuracy: 0.8475 - val_loss: 0.4615 - val_accuracy: 0.7138
# Epoch 45/75
# 12/12 [==============================] - 2s 179ms/step - loss: 0.0741 - accuracy: 0.8492 - val_loss: 0.4476 - val_accuracy: 0.7281
# Epoch 46/75
# 12/12 [==============================] - 3s 223ms/step - loss: 0.0743 - accuracy: 0.8508 - val_loss: 0.4560 - val_accuracy: 0.7229
# Epoch 47/75
# 12/12 [==============================] - 2s 198ms/step - loss: 0.0746 - accuracy: 0.8576 - val_loss: 0.4587 - val_accuracy: 0.7307
# Epoch 48/75
# 12/12 [==============================] - 2s 206ms/step - loss: 0.0681 - accuracy: 0.8589 - val_loss: 0.4574 - val_accuracy: 0.7287
# Epoch 49/75
# 12/12 [==============================] - 3s 216ms/step - loss: 0.0683 - accuracy: 0.8641 - val_loss: 0.4388 - val_accuracy: 0.7236
# Epoch 50/75
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0729 - accuracy: 0.8590 - val_loss: 0.4689 - val_accuracy: 0.7502
# Epoch 51/75
# 12/12 [==============================] - 2s 146ms/step - loss: 0.0670 - accuracy: 0.8735 - val_loss: 0.4922 - val_accuracy: 0.7313
# Epoch 52/75
# 12/12 [==============================] - 2s 136ms/step - loss: 0.0701 - accuracy: 0.8631 - val_loss: 0.4572 - val_accuracy: 0.7352
# Epoch 53/75
# 12/12 [==============================] - 2s 146ms/step - loss: 0.0627 - accuracy: 0.8716 - val_loss: 0.4843 - val_accuracy: 0.7573
# Epoch 54/75
# 12/12 [==============================] - 2s 140ms/step - loss: 0.0609 - accuracy: 0.8892 - val_loss: 0.5075 - val_accuracy: 0.7495
# Epoch 55/75
# 12/12 [==============================] - 2s 130ms/step - loss: 0.0589 - accuracy: 0.8837 - val_loss: 0.5412 - val_accuracy: 0.7729
# Epoch 56/75
# 12/12 [==============================] - 2s 134ms/step - loss: 0.0585 - accuracy: 0.8946 - val_loss: 0.5011 - val_accuracy: 0.7579
# Epoch 57/75
# 12/12 [==============================] - 2s 139ms/step - loss: 0.0535 - accuracy: 0.8940 - val_loss: 0.4659 - val_accuracy: 0.7755
# Epoch 58/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0589 - accuracy: 0.8906 - val_loss: 0.4908 - val_accuracy: 0.7683
# Epoch 59/75
# 12/12 [==============================] - 2s 171ms/step - loss: 0.0512 - accuracy: 0.9021 - val_loss: 0.5194 - val_accuracy: 0.7625
# Epoch 60/75
# 12/12 [==============================] - 2s 153ms/step - loss: 0.0578 - accuracy: 0.8856 - val_loss: 0.5111 - val_accuracy: 0.7664
# Epoch 61/75
# 12/12 [==============================] - 2s 162ms/step - loss: 0.0532 - accuracy: 0.8985 - val_loss: 0.4867 - val_accuracy: 0.7515
# Epoch 62/75
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0521 - accuracy: 0.8978 - val_loss: 0.5208 - val_accuracy: 0.7722
# Epoch 63/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0457 - accuracy: 0.9151 - val_loss: 0.5242 - val_accuracy: 0.7917
# Epoch 64/75
# 12/12 [==============================] - 2s 158ms/step - loss: 0.0538 - accuracy: 0.9022 - val_loss: 0.5132 - val_accuracy: 0.7826
# Epoch 65/75
# 12/12 [==============================] - 2s 138ms/step - loss: 0.0488 - accuracy: 0.9100 - val_loss: 0.5319 - val_accuracy: 0.7800
# Epoch 66/75
# 12/12 [==============================] - 2s 159ms/step - loss: 0.0494 - accuracy: 0.9004 - val_loss: 0.5144 - val_accuracy: 0.7631
# Epoch 67/75
# 12/12 [==============================] - 2s 152ms/step - loss: 0.0528 - accuracy: 0.9088 - val_loss: 0.5329 - val_accuracy: 0.7748
# Epoch 68/75
# 12/12 [==============================] - 2s 140ms/step - loss: 0.0450 - accuracy: 0.9135 - val_loss: 0.5267 - val_accuracy: 0.7677
# Epoch 69/75
# 12/12 [==============================] - 2s 148ms/step - loss: 0.0425 - accuracy: 0.9163 - val_loss: 0.5136 - val_accuracy: 0.7586
# Epoch 70/75
# 12/12 [==============================] - 2s 158ms/step - loss: 0.0510 - accuracy: 0.8930 - val_loss: 0.5398 - val_accuracy: 0.7904
# Epoch 71/75
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0529 - accuracy: 0.9128 - val_loss: 0.5408 - val_accuracy: 0.7891
# Epoch 72/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0460 - accuracy: 0.9165 - val_loss: 0.5698 - val_accuracy: 0.7878
# Epoch 73/75
# 12/12 [==============================] - 2s 146ms/step - loss: 0.0373 - accuracy: 0.9271 - val_loss: 0.5304 - val_accuracy: 0.7936
# Epoch 74/75
# 12/12 [==============================] - 2s 140ms/step - loss: 0.0414 - accuracy: 0.9203 - val_loss: 0.5248 - val_accuracy: 0.7884
# Epoch 75/75
# 12/12 [==============================] - 2s 131ms/step - loss: 0.0373 - accuracy: 0.9248 - val_loss: 0.5735 - val_accuracy: 0.8034
# Iteration:	3
# EMBEDDING:	text_vectorization
# STOP_WORDS:	False
# LEMMATIZATION:	True
# HIDDEN_DIM:	32
# LSTM_STACK:	True
# DROP_OUT:	True
# SAMPLE_WEIGHTS:	False
# TRAINABLE:	True
#
# Epoch 1/75
# 12/12 [==============================] - 19s 346ms/step - loss: 0.3524 - accuracy: 0.4638 - val_loss: 0.2981 - val_accuracy: 0.5445
# Epoch 2/75
# 12/12 [==============================] - 2s 145ms/step - loss: 0.3157 - accuracy: 0.5595 - val_loss: 0.2752 - val_accuracy: 0.5516
# Epoch 3/75
# 12/12 [==============================] - 2s 149ms/step - loss: 0.2999 - accuracy: 0.5885 - val_loss: 0.2547 - val_accuracy: 0.6541
# Epoch 4/75
# 12/12 [==============================] - 2s 139ms/step - loss: 0.2630 - accuracy: 0.6640 - val_loss: 0.2345 - val_accuracy: 0.6684
# Epoch 5/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.2258 - accuracy: 0.7058 - val_loss: 0.2244 - val_accuracy: 0.6853
# Epoch 6/75
# 12/12 [==============================] - 2s 149ms/step - loss: 0.2137 - accuracy: 0.7456 - val_loss: 0.2090 - val_accuracy: 0.7171
# Epoch 7/75
# 12/12 [==============================] - 2s 158ms/step - loss: 0.1868 - accuracy: 0.7775 - val_loss: 0.1961 - val_accuracy: 0.7281
# Epoch 8/75
# 12/12 [==============================] - 2s 156ms/step - loss: 0.1868 - accuracy: 0.7808 - val_loss: 0.2039 - val_accuracy: 0.7443
# Epoch 9/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.1636 - accuracy: 0.8064 - val_loss: 0.1833 - val_accuracy: 0.7599
# Epoch 10/75
# 12/12 [==============================] - 2s 149ms/step - loss: 0.1432 - accuracy: 0.8375 - val_loss: 0.1808 - val_accuracy: 0.7670
# Epoch 11/75
# 12/12 [==============================] - 2s 146ms/step - loss: 0.1379 - accuracy: 0.8448 - val_loss: 0.1800 - val_accuracy: 0.7774
# Epoch 12/75
# 12/12 [==============================] - 2s 176ms/step - loss: 0.1289 - accuracy: 0.8615 - val_loss: 0.1713 - val_accuracy: 0.7807
# Epoch 13/75
# 12/12 [==============================] - 2s 150ms/step - loss: 0.1196 - accuracy: 0.8701 - val_loss: 0.1727 - val_accuracy: 0.7859
# Epoch 14/75
# 12/12 [==============================] - 2s 155ms/step - loss: 0.1085 - accuracy: 0.8832 - val_loss: 0.1702 - val_accuracy: 0.7936
# Epoch 15/75
# 12/12 [==============================] - 2s 158ms/step - loss: 0.1099 - accuracy: 0.8745 - val_loss: 0.1735 - val_accuracy: 0.7813
# Epoch 16/75
# 12/12 [==============================] - 2s 165ms/step - loss: 0.1040 - accuracy: 0.8806 - val_loss: 0.1693 - val_accuracy: 0.7859
# Epoch 17/75
# 12/12 [==============================] - 2s 152ms/step - loss: 0.0968 - accuracy: 0.8950 - val_loss: 0.1609 - val_accuracy: 0.8047
# Epoch 18/75
# 12/12 [==============================] - 2s 162ms/step - loss: 0.0959 - accuracy: 0.8958 - val_loss: 0.1706 - val_accuracy: 0.8079
# Epoch 19/75
# 12/12 [==============================] - 2s 176ms/step - loss: 0.0954 - accuracy: 0.9011 - val_loss: 0.1662 - val_accuracy: 0.8034
# Epoch 20/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0830 - accuracy: 0.9100 - val_loss: 0.1643 - val_accuracy: 0.8170
# Epoch 21/75
# 12/12 [==============================] - 2s 172ms/step - loss: 0.0823 - accuracy: 0.9091 - val_loss: 0.1579 - val_accuracy: 0.8164
# Epoch 22/75
# 12/12 [==============================] - 2s 159ms/step - loss: 0.0816 - accuracy: 0.9113 - val_loss: 0.1613 - val_accuracy: 0.8202
# Epoch 23/75
# 12/12 [==============================] - 2s 172ms/step - loss: 0.0783 - accuracy: 0.9213 - val_loss: 0.1633 - val_accuracy: 0.8248
# Epoch 24/75
# 12/12 [==============================] - 2s 174ms/step - loss: 0.0752 - accuracy: 0.9266 - val_loss: 0.1595 - val_accuracy: 0.8248
# Epoch 25/75
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0675 - accuracy: 0.9295 - val_loss: 0.1545 - val_accuracy: 0.8241
# Epoch 26/75
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0652 - accuracy: 0.9321 - val_loss: 0.1650 - val_accuracy: 0.8196
# Epoch 27/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0667 - accuracy: 0.9296 - val_loss: 0.1726 - val_accuracy: 0.8293
# Epoch 28/75
# 12/12 [==============================] - 2s 151ms/step - loss: 0.0643 - accuracy: 0.9301 - val_loss: 0.1650 - val_accuracy: 0.8352
# Epoch 29/75
# 12/12 [==============================] - 2s 147ms/step - loss: 0.0557 - accuracy: 0.9411 - val_loss: 0.1668 - val_accuracy: 0.8365
# Epoch 30/75
# 12/12 [==============================] - 2s 144ms/step - loss: 0.0534 - accuracy: 0.9406 - val_loss: 0.1571 - val_accuracy: 0.8436
# Epoch 31/75
# 12/12 [==============================] - 2s 145ms/step - loss: 0.0537 - accuracy: 0.9435 - val_loss: 0.1671 - val_accuracy: 0.8391
# Epoch 32/75
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0563 - accuracy: 0.9405 - val_loss: 0.1618 - val_accuracy: 0.8306
# Epoch 33/75
# 12/12 [==============================] - 2s 146ms/step - loss: 0.0512 - accuracy: 0.9510 - val_loss: 0.1605 - val_accuracy: 0.8384
# Epoch 34/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0435 - accuracy: 0.9522 - val_loss: 0.1675 - val_accuracy: 0.8456
# Epoch 35/75
# 12/12 [==============================] - 2s 152ms/step - loss: 0.0430 - accuracy: 0.9551 - val_loss: 0.1654 - val_accuracy: 0.8443
# Epoch 36/75
# 12/12 [==============================] - 2s 147ms/step - loss: 0.0521 - accuracy: 0.9484 - val_loss: 0.1622 - val_accuracy: 0.8456
# Epoch 37/75
# 12/12 [==============================] - 2s 149ms/step - loss: 0.0458 - accuracy: 0.9509 - val_loss: 0.1638 - val_accuracy: 0.8423
# Epoch 38/75
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0409 - accuracy: 0.9592 - val_loss: 0.1726 - val_accuracy: 0.8384
# Epoch 39/75
# 12/12 [==============================] - 2s 149ms/step - loss: 0.0424 - accuracy: 0.9602 - val_loss: 0.1678 - val_accuracy: 0.8469
# Epoch 40/75
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0386 - accuracy: 0.9600 - val_loss: 0.1666 - val_accuracy: 0.8507
# Epoch 41/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0333 - accuracy: 0.9665 - val_loss: 0.1707 - val_accuracy: 0.8475
# Epoch 42/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0358 - accuracy: 0.9675 - val_loss: 0.1700 - val_accuracy: 0.8456
# Epoch 43/75
# 12/12 [==============================] - 2s 145ms/step - loss: 0.0331 - accuracy: 0.9664 - val_loss: 0.1681 - val_accuracy: 0.8482
# Epoch 44/75
# 12/12 [==============================] - 2s 145ms/step - loss: 0.0316 - accuracy: 0.9697 - val_loss: 0.1696 - val_accuracy: 0.8494
# Epoch 45/75
# 12/12 [==============================] - 2s 140ms/step - loss: 0.0299 - accuracy: 0.9704 - val_loss: 0.1760 - val_accuracy: 0.8423
# Epoch 46/75
# 12/12 [==============================] - 2s 146ms/step - loss: 0.0315 - accuracy: 0.9677 - val_loss: 0.1813 - val_accuracy: 0.8456
# Epoch 47/75
# 12/12 [==============================] - 2s 159ms/step - loss: 0.0314 - accuracy: 0.9694 - val_loss: 0.1730 - val_accuracy: 0.8469
# Epoch 48/75
# 12/12 [==============================] - 2s 147ms/step - loss: 0.0249 - accuracy: 0.9737 - val_loss: 0.1927 - val_accuracy: 0.8456
# Epoch 49/75
# 12/12 [==============================] - 2s 155ms/step - loss: 0.0295 - accuracy: 0.9685 - val_loss: 0.1701 - val_accuracy: 0.8546
# Epoch 50/75
# 12/12 [==============================] - 2s 156ms/step - loss: 0.0303 - accuracy: 0.9688 - val_loss: 0.1855 - val_accuracy: 0.8469
# Epoch 51/75
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0270 - accuracy: 0.9712 - val_loss: 0.1888 - val_accuracy: 0.8436
# Epoch 52/75
# 12/12 [==============================] - 2s 175ms/step - loss: 0.0304 - accuracy: 0.9689 - val_loss: 0.1794 - val_accuracy: 0.8469
# Epoch 53/75
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0263 - accuracy: 0.9741 - val_loss: 0.1801 - val_accuracy: 0.8482
# Epoch 54/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0221 - accuracy: 0.9789 - val_loss: 0.1816 - val_accuracy: 0.8482
# Epoch 55/75
# 12/12 [==============================] - 2s 178ms/step - loss: 0.0216 - accuracy: 0.9784 - val_loss: 0.1925 - val_accuracy: 0.8462
# Epoch 56/75
# 12/12 [==============================] - 2s 148ms/step - loss: 0.0198 - accuracy: 0.9833 - val_loss: 0.1811 - val_accuracy: 0.8533
# Epoch 57/75
# 12/12 [==============================] - 2s 152ms/step - loss: 0.0234 - accuracy: 0.9784 - val_loss: 0.1958 - val_accuracy: 0.8507
# Epoch 58/75
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0243 - accuracy: 0.9760 - val_loss: 0.1921 - val_accuracy: 0.8462
# Epoch 59/75
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0208 - accuracy: 0.9792 - val_loss: 0.1865 - val_accuracy: 0.8501
# Epoch 60/75
# 12/12 [==============================] - 2s 141ms/step - loss: 0.0224 - accuracy: 0.9752 - val_loss: 0.1920 - val_accuracy: 0.8553
# Epoch 61/75
# 12/12 [==============================] - 2s 155ms/step - loss: 0.0186 - accuracy: 0.9807 - val_loss: 0.1861 - val_accuracy: 0.8514
# Epoch 62/75
# 12/12 [==============================] - 2s 146ms/step - loss: 0.0195 - accuracy: 0.9790 - val_loss: 0.1861 - val_accuracy: 0.8514
# Epoch 63/75
# 12/12 [==============================] - 2s 147ms/step - loss: 0.0208 - accuracy: 0.9810 - val_loss: 0.1894 - val_accuracy: 0.8514
# Epoch 64/75
# 12/12 [==============================] - 2s 147ms/step - loss: 0.0201 - accuracy: 0.9784 - val_loss: 0.2072 - val_accuracy: 0.8469
# Epoch 65/75
# 12/12 [==============================] - 2s 153ms/step - loss: 0.0218 - accuracy: 0.9782 - val_loss: 0.1917 - val_accuracy: 0.8482
# Epoch 66/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0173 - accuracy: 0.9806 - val_loss: 0.2008 - val_accuracy: 0.8462
# Epoch 67/75
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0167 - accuracy: 0.9833 - val_loss: 0.1970 - val_accuracy: 0.8514
# Epoch 68/75
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0175 - accuracy: 0.9810 - val_loss: 0.1983 - val_accuracy: 0.8540
# Epoch 69/75
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0162 - accuracy: 0.9832 - val_loss: 0.2035 - val_accuracy: 0.8501
# Epoch 70/75
# 12/12 [==============================] - 2s 145ms/step - loss: 0.0188 - accuracy: 0.9797 - val_loss: 0.2015 - val_accuracy: 0.8449
# Epoch 71/75
# 12/12 [==============================] - 2s 153ms/step - loss: 0.0214 - accuracy: 0.9780 - val_loss: 0.2043 - val_accuracy: 0.8494
# Epoch 72/75
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0169 - accuracy: 0.9829 - val_loss: 0.2185 - val_accuracy: 0.8501
# Epoch 73/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0128 - accuracy: 0.9857 - val_loss: 0.2152 - val_accuracy: 0.8469
# Epoch 74/75
# 12/12 [==============================] - 2s 156ms/step - loss: 0.0184 - accuracy: 0.9792 - val_loss: 0.2048 - val_accuracy: 0.8546
# Epoch 75/75
# 12/12 [==============================] - 2s 169ms/step - loss: 0.0143 - accuracy: 0.9871 - val_loss: 0.1975 - val_accuracy: 0.8533
# Iteration:	4
# EMBEDDING:	text_vectorization
# STOP_WORDS:	False
# LEMMATIZATION:	True
# HIDDEN_DIM:	32
# LSTM_STACK:	True
# DROP_OUT:	True
# SAMPLE_WEIGHTS:	False
# TRAINABLE:	False
#
# Epoch 1/75
# 12/12 [==============================] - 15s 305ms/step - loss: 0.3511 - accuracy: 0.4890 - val_loss: 0.2938 - val_accuracy: 0.5445
# Epoch 2/75
# 12/12 [==============================] - 2s 147ms/step - loss: 0.3137 - accuracy: 0.5597 - val_loss: 0.2712 - val_accuracy: 0.5587
# Epoch 3/75
# 12/12 [==============================] - 2s 151ms/step - loss: 0.2960 - accuracy: 0.5926 - val_loss: 0.2505 - val_accuracy: 0.6269
# Epoch 4/75
# 12/12 [==============================] - 2s 158ms/step - loss: 0.2590 - accuracy: 0.6610 - val_loss: 0.2306 - val_accuracy: 0.6723
# Epoch 5/75
# 12/12 [==============================] - 2s 145ms/step - loss: 0.2189 - accuracy: 0.7132 - val_loss: 0.2152 - val_accuracy: 0.7223
# Epoch 6/75
# 12/12 [==============================] - 2s 146ms/step - loss: 0.2089 - accuracy: 0.7584 - val_loss: 0.1977 - val_accuracy: 0.7482
# Epoch 7/75
# 12/12 [==============================] - 2s 158ms/step - loss: 0.1820 - accuracy: 0.7839 - val_loss: 0.1919 - val_accuracy: 0.7612
# Epoch 8/75
# 12/12 [==============================] - 2s 186ms/step - loss: 0.1775 - accuracy: 0.7995 - val_loss: 0.1807 - val_accuracy: 0.7670
# Epoch 9/75
# 12/12 [==============================] - 2s 170ms/step - loss: 0.1580 - accuracy: 0.8209 - val_loss: 0.1715 - val_accuracy: 0.7872
# Epoch 10/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.1390 - accuracy: 0.8309 - val_loss: 0.1769 - val_accuracy: 0.7735
# Epoch 11/75
# 12/12 [==============================] - 2s 169ms/step - loss: 0.1408 - accuracy: 0.8430 - val_loss: 0.1693 - val_accuracy: 0.7859
# Epoch 12/75
# 12/12 [==============================] - 2s 177ms/step - loss: 0.1260 - accuracy: 0.8605 - val_loss: 0.1614 - val_accuracy: 0.7982
# Epoch 13/75
# 12/12 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.86 - 2s 167ms/step - loss: 0.1209 - accuracy: 0.8685 - val_loss: 0.1632 - val_accuracy: 0.7956
# Epoch 14/75
# 12/12 [==============================] - 2s 203ms/step - loss: 0.1089 - accuracy: 0.8826 - val_loss: 0.1543 - val_accuracy: 0.8027
# Epoch 15/75
# 12/12 [==============================] - 2s 171ms/step - loss: 0.1103 - accuracy: 0.8765 - val_loss: 0.1583 - val_accuracy: 0.8047
# Epoch 16/75
# 12/12 [==============================] - 2s 163ms/step - loss: 0.1030 - accuracy: 0.8860 - val_loss: 0.1519 - val_accuracy: 0.8105
# Epoch 17/75
# 12/12 [==============================] - 2s 172ms/step - loss: 0.0952 - accuracy: 0.9005 - val_loss: 0.1574 - val_accuracy: 0.8138
# Epoch 18/75
# 12/12 [==============================] - 2s 174ms/step - loss: 0.0964 - accuracy: 0.8905 - val_loss: 0.1580 - val_accuracy: 0.8099
# Epoch 19/75
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0939 - accuracy: 0.9017 - val_loss: 0.1489 - val_accuracy: 0.8202
# Epoch 20/75
# 12/12 [==============================] - 2s 169ms/step - loss: 0.0852 - accuracy: 0.9056 - val_loss: 0.1553 - val_accuracy: 0.8144
# Epoch 21/75
# 12/12 [==============================] - 2s 156ms/step - loss: 0.0877 - accuracy: 0.9015 - val_loss: 0.1514 - val_accuracy: 0.8248
# Epoch 22/75
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0797 - accuracy: 0.9176 - val_loss: 0.1511 - val_accuracy: 0.8228
# Epoch 23/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0794 - accuracy: 0.9101 - val_loss: 0.1460 - val_accuracy: 0.8287
# Epoch 24/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0711 - accuracy: 0.9362 - val_loss: 0.1484 - val_accuracy: 0.8332
# Epoch 25/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0634 - accuracy: 0.9363 - val_loss: 0.1471 - val_accuracy: 0.8352
# Epoch 26/75
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0619 - accuracy: 0.9328 - val_loss: 0.1633 - val_accuracy: 0.8235
# Epoch 27/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0655 - accuracy: 0.9293 - val_loss: 0.1512 - val_accuracy: 0.8358
# Epoch 28/75
# 12/12 [==============================] - 2s 178ms/step - loss: 0.0536 - accuracy: 0.9474 - val_loss: 0.1524 - val_accuracy: 0.8332
# Epoch 29/75
# 12/12 [==============================] - 2s 178ms/step - loss: 0.0561 - accuracy: 0.9415 - val_loss: 0.1582 - val_accuracy: 0.8365
# Epoch 30/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0544 - accuracy: 0.9410 - val_loss: 0.1518 - val_accuracy: 0.8436
# Epoch 31/75
# 12/12 [==============================] - 2s 156ms/step - loss: 0.0489 - accuracy: 0.9505 - val_loss: 0.1500 - val_accuracy: 0.8371
# Epoch 32/75
# 12/12 [==============================] - 2s 153ms/step - loss: 0.0486 - accuracy: 0.9467 - val_loss: 0.1632 - val_accuracy: 0.8371
# Epoch 33/75
# 12/12 [==============================] - 2s 153ms/step - loss: 0.0449 - accuracy: 0.9539 - val_loss: 0.1583 - val_accuracy: 0.8469
# Epoch 34/75
# 12/12 [==============================] - 2s 162ms/step - loss: 0.0426 - accuracy: 0.9546 - val_loss: 0.1572 - val_accuracy: 0.8430
# Epoch 35/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0424 - accuracy: 0.9530 - val_loss: 0.1564 - val_accuracy: 0.8494
# Epoch 36/75
# 12/12 [==============================] - 2s 180ms/step - loss: 0.0471 - accuracy: 0.9497 - val_loss: 0.1578 - val_accuracy: 0.8391
# Epoch 37/75
# 12/12 [==============================] - 2s 197ms/step - loss: 0.0414 - accuracy: 0.9564 - val_loss: 0.1686 - val_accuracy: 0.8417
# Epoch 38/75
# 12/12 [==============================] - 2s 177ms/step - loss: 0.0368 - accuracy: 0.9631 - val_loss: 0.1581 - val_accuracy: 0.8488
# Epoch 39/75
# 12/12 [==============================] - 2s 183ms/step - loss: 0.0387 - accuracy: 0.9617 - val_loss: 0.1691 - val_accuracy: 0.8546
# Epoch 40/75
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0362 - accuracy: 0.9620 - val_loss: 0.1670 - val_accuracy: 0.8482
# Epoch 41/75
# 12/12 [==============================] - 2s 185ms/step - loss: 0.0340 - accuracy: 0.9618 - val_loss: 0.1606 - val_accuracy: 0.8553
# Epoch 42/75
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0339 - accuracy: 0.9665 - val_loss: 0.1619 - val_accuracy: 0.8540
# Epoch 43/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0276 - accuracy: 0.9722 - val_loss: 0.1651 - val_accuracy: 0.8501
# Epoch 44/75
# 12/12 [==============================] - 2s 171ms/step - loss: 0.0299 - accuracy: 0.9733 - val_loss: 0.1678 - val_accuracy: 0.8572
# Epoch 45/75
# 12/12 [==============================] - 2s 161ms/step - loss: 0.0289 - accuracy: 0.9710 - val_loss: 0.1719 - val_accuracy: 0.8520
# Epoch 46/75
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0322 - accuracy: 0.9642 - val_loss: 0.1632 - val_accuracy: 0.8566
# Epoch 47/75
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0298 - accuracy: 0.9674 - val_loss: 0.1710 - val_accuracy: 0.8507
# Epoch 48/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0268 - accuracy: 0.9717 - val_loss: 0.1606 - val_accuracy: 0.8553
# Epoch 49/75
# 12/12 [==============================] - 2s 160ms/step - loss: 0.0226 - accuracy: 0.9763 - val_loss: 0.1709 - val_accuracy: 0.8488
# Epoch 50/75
# 12/12 [==============================] - 2s 158ms/step - loss: 0.0291 - accuracy: 0.9698 - val_loss: 0.1778 - val_accuracy: 0.8501
# Epoch 51/75
# 12/12 [==============================] - 2s 156ms/step - loss: 0.0227 - accuracy: 0.9781 - val_loss: 0.1748 - val_accuracy: 0.8520
# Epoch 52/75
# 12/12 [==============================] - 2s 162ms/step - loss: 0.0247 - accuracy: 0.9737 - val_loss: 0.1787 - val_accuracy: 0.8592
# Epoch 53/75
# 12/12 [==============================] - 2s 166ms/step - loss: 0.0271 - accuracy: 0.9724 - val_loss: 0.1772 - val_accuracy: 0.8624
# Epoch 54/75
# 12/12 [==============================] - 2s 156ms/step - loss: 0.0217 - accuracy: 0.9761 - val_loss: 0.1784 - val_accuracy: 0.8592
# Epoch 55/75
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0226 - accuracy: 0.9766 - val_loss: 0.1881 - val_accuracy: 0.8572
# Epoch 56/75
# 12/12 [==============================] - 2s 160ms/step - loss: 0.0209 - accuracy: 0.9789 - val_loss: 0.1819 - val_accuracy: 0.8566
# Epoch 57/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0217 - accuracy: 0.9777 - val_loss: 0.2026 - val_accuracy: 0.8566
# Epoch 58/75
# 12/12 [==============================] - 2s 155ms/step - loss: 0.0253 - accuracy: 0.9730 - val_loss: 0.1830 - val_accuracy: 0.8540
# Epoch 59/75
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0185 - accuracy: 0.9801 - val_loss: 0.1887 - val_accuracy: 0.8520
# Epoch 60/75
# 12/12 [==============================] - 2s 156ms/step - loss: 0.0179 - accuracy: 0.9814 - val_loss: 0.1966 - val_accuracy: 0.8540
# Epoch 61/75
# 12/12 [==============================] - 2s 171ms/step - loss: 0.0186 - accuracy: 0.9822 - val_loss: 0.1812 - val_accuracy: 0.8566
# Epoch 62/75
# 12/12 [==============================] - 2s 159ms/step - loss: 0.0214 - accuracy: 0.9778 - val_loss: 0.1870 - val_accuracy: 0.8507
# Epoch 63/75
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0177 - accuracy: 0.9818 - val_loss: 0.1944 - val_accuracy: 0.8559
# Epoch 64/75
# 12/12 [==============================] - 2s 156ms/step - loss: 0.0159 - accuracy: 0.9809 - val_loss: 0.2032 - val_accuracy: 0.8527
# Epoch 65/75
# 12/12 [==============================] - 2s 164ms/step - loss: 0.0213 - accuracy: 0.9755 - val_loss: 0.1985 - val_accuracy: 0.8533
# Epoch 66/75
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0136 - accuracy: 0.9870 - val_loss: 0.1940 - val_accuracy: 0.8585
# Epoch 67/75
# 12/12 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.98 - 2s 155ms/step - loss: 0.0170 - accuracy: 0.9831 - val_loss: 0.1942 - val_accuracy: 0.8598
# Epoch 68/75
# 12/12 [==============================] - 2s 154ms/step - loss: 0.0166 - accuracy: 0.9842 - val_loss: 0.2047 - val_accuracy: 0.8566
# Epoch 69/75
# 12/12 [==============================] - 2s 159ms/step - loss: 0.0167 - accuracy: 0.9837 - val_loss: 0.1910 - val_accuracy: 0.8559
# Epoch 70/75
# 12/12 [==============================] - 2s 171ms/step - loss: 0.0161 - accuracy: 0.9828 - val_loss: 0.1935 - val_accuracy: 0.8611
# Epoch 71/75
# 12/12 [==============================] - 2s 158ms/step - loss: 0.0186 - accuracy: 0.9803 - val_loss: 0.1909 - val_accuracy: 0.8605
# Epoch 72/75
# 12/12 [==============================] - 2s 160ms/step - loss: 0.0147 - accuracy: 0.9857 - val_loss: 0.1964 - val_accuracy: 0.8566
# Epoch 73/75
# 12/12 [==============================] - 2s 159ms/step - loss: 0.0115 - accuracy: 0.9889 - val_loss: 0.2111 - val_accuracy: 0.8507
# Epoch 74/75
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0153 - accuracy: 0.9831 - val_loss: 0.2010 - val_accuracy: 0.8559
# Epoch 75/75
# 12/12 [==============================] - 2s 159ms/step - loss: 0.0134 - accuracy: 0.9865 - val_loss: 0.2078 - val_accuracy: 0.8572
# Iteration:	5
# EMBEDDING:	text_vectorization
# STOP_WORDS:	False
# LEMMATIZATION:	True
# HIDDEN_DIM:	32
# LSTM_STACK:	False
# DROP_OUT:	True
# SAMPLE_WEIGHTS:	True
# TRAINABLE:	True
#
# Epoch 1/75
# 12/12 [==============================] - 13s 253ms/step - loss: 0.7995 - accuracy: 0.3293 - val_loss: 0.6216 - val_accuracy: 0.3621
# Epoch 2/75
# 12/12 [==============================] - 1s 114ms/step - loss: 0.6187 - accuracy: 0.3633 - val_loss: 0.5102 - val_accuracy: 0.3809
# Epoch 3/75
# 12/12 [==============================] - 2s 133ms/step - loss: 0.5433 - accuracy: 0.3825 - val_loss: 0.4499 - val_accuracy: 0.3913
# Epoch 4/75
# 12/12 [==============================] - 2s 138ms/step - loss: 0.4622 - accuracy: 0.3919 - val_loss: 0.4153 - val_accuracy: 0.4017
# Epoch 5/75
# 12/12 [==============================] - 1s 122ms/step - loss: 0.3829 - accuracy: 0.4348 - val_loss: 0.3876 - val_accuracy: 0.4062
# Epoch 6/75
# 12/12 [==============================] - 2s 144ms/step - loss: 0.3632 - accuracy: 0.4363 - val_loss: 0.3747 - val_accuracy: 0.4082
# Epoch 7/75
# 12/12 [==============================] - 1s 118ms/step - loss: 0.3178 - accuracy: 0.4699 - val_loss: 0.3764 - val_accuracy: 0.4108
# Epoch 8/75
# 12/12 [==============================] - 1s 119ms/step - loss: 0.3343 - accuracy: 0.4471 - val_loss: 0.3534 - val_accuracy: 0.4153
# Epoch 9/75
# 12/12 [==============================] - 2s 138ms/step - loss: 0.2854 - accuracy: 0.4710 - val_loss: 0.3515 - val_accuracy: 0.4186
# Epoch 10/75
# 12/12 [==============================] - 2s 142ms/step - loss: 0.2770 - accuracy: 0.4735 - val_loss: 0.3633 - val_accuracy: 0.4218
# Epoch 11/75
# 12/12 [==============================] - 1s 125ms/step - loss: 0.2678 - accuracy: 0.4808 - val_loss: 0.3350 - val_accuracy: 0.4432
# Epoch 12/75
# 12/12 [==============================] - 2s 146ms/step - loss: 0.2533 - accuracy: 0.4831 - val_loss: 0.3324 - val_accuracy: 0.4510
# Epoch 13/75
# 12/12 [==============================] - 2s 127ms/step - loss: 0.2420 - accuracy: 0.5080 - val_loss: 0.3329 - val_accuracy: 0.4607
# Epoch 14/75
# 12/12 [==============================] - 2s 136ms/step - loss: 0.2313 - accuracy: 0.5143 - val_loss: 0.3255 - val_accuracy: 0.4744
# Epoch 15/75
# 12/12 [==============================] - 1s 116ms/step - loss: 0.2120 - accuracy: 0.5233 - val_loss: 0.3246 - val_accuracy: 0.4737
# Epoch 16/75
# 12/12 [==============================] - 1s 114ms/step - loss: 0.2138 - accuracy: 0.5257 - val_loss: 0.3466 - val_accuracy: 0.4698
# Epoch 17/75
# 12/12 [==============================] - 1s 106ms/step - loss: 0.1951 - accuracy: 0.5445 - val_loss: 0.3411 - val_accuracy: 0.4809
# Epoch 18/75
# 12/12 [==============================] - 1s 113ms/step - loss: 0.1923 - accuracy: 0.5608 - val_loss: 0.3285 - val_accuracy: 0.5295
# Epoch 19/75
# 12/12 [==============================] - 1s 107ms/step - loss: 0.1909 - accuracy: 0.5926 - val_loss: 0.3416 - val_accuracy: 0.5341
# Epoch 20/75
# 12/12 [==============================] - 1s 107ms/step - loss: 0.1784 - accuracy: 0.6076 - val_loss: 0.3325 - val_accuracy: 0.5704
# Epoch 21/75
# 12/12 [==============================] - 1s 110ms/step - loss: 0.1743 - accuracy: 0.6259 - val_loss: 0.3215 - val_accuracy: 0.5886
# Epoch 22/75
# 12/12 [==============================] - 1s 122ms/step - loss: 0.1609 - accuracy: 0.6468 - val_loss: 0.3266 - val_accuracy: 0.6158
# Epoch 23/75
# 12/12 [==============================] - 2s 128ms/step - loss: 0.1666 - accuracy: 0.6675 - val_loss: 0.3209 - val_accuracy: 0.6113
# Epoch 24/75
# 12/12 [==============================] - 1s 125ms/step - loss: 0.1514 - accuracy: 0.6904 - val_loss: 0.3170 - val_accuracy: 0.6379
# Epoch 25/75
# 12/12 [==============================] - 2s 137ms/step - loss: 0.1312 - accuracy: 0.7258 - val_loss: 0.3204 - val_accuracy: 0.6450
# Epoch 26/75
# 12/12 [==============================] - 1s 118ms/step - loss: 0.1242 - accuracy: 0.7448 - val_loss: 0.3242 - val_accuracy: 0.6911
# Epoch 27/75
# 12/12 [==============================] - 1s 115ms/step - loss: 0.1264 - accuracy: 0.7578 - val_loss: 0.3186 - val_accuracy: 0.6749
# Epoch 28/75
# 12/12 [==============================] - 1s 112ms/step - loss: 0.1167 - accuracy: 0.7716 - val_loss: 0.3264 - val_accuracy: 0.6548
# Epoch 29/75
# 12/12 [==============================] - 1s 109ms/step - loss: 0.1146 - accuracy: 0.7642 - val_loss: 0.3238 - val_accuracy: 0.7125
# Epoch 30/75
# ...
# Epoch 41/75
# 12/12 [==============================] - 8s 672ms/step - loss: 0.0032 - accuracy: 0.9968 - val_loss: 0.2372 - val_accuracy: 0.8611
# Epoch 42/75
# 12/12 [==============================] - 8s 653ms/step - loss: 0.0037 - accuracy: 0.9954 - val_loss: 0.2220 - val_accuracy: 0.8631
# Epoch 43/75
# 12/12 [==============================] - 8s 669ms/step - loss: 0.0056 - accuracy: 0.9918 - val_loss: 0.2219 - val_accuracy: 0.8605
# Epoch 44/75
# 12/12 [==============================] - 8s 651ms/step - loss: 0.0042 - accuracy: 0.9960 - val_loss: 0.2217 - val_accuracy: 0.8650
# Epoch 45/75
# 12/12 [==============================] - 8s 673ms/step - loss: 0.0034 - accuracy: 0.9949 - val_loss: 0.2298 - val_accuracy: 0.8598
# Epoch 46/75
# 12/12 [==============================] - 8s 663ms/step - loss: 0.0049 - accuracy: 0.9936 - val_loss: 0.2258 - val_accuracy: 0.8592
# Epoch 47/75
# 12/12 [==============================] - 8s 675ms/step - loss: 0.0042 - accuracy: 0.9939 - val_loss: 0.2284 - val_accuracy: 0.8670
# Epoch 48/75
# 12/12 [==============================] - 8s 655ms/step - loss: 0.0049 - accuracy: 0.9943 - val_loss: 0.2406 - val_accuracy: 0.8598
# Epoch 49/75
# 12/12 [==============================] - 8s 670ms/step - loss: 0.0048 - accuracy: 0.9928 - val_loss: 0.2291 - val_accuracy: 0.8683
# Epoch 50/75
# 12/12 [==============================] - 8s 659ms/step - loss: 0.0031 - accuracy: 0.9962 - val_loss: 0.2427 - val_accuracy: 0.8657
# Epoch 51/75
# 12/12 [==============================] - 8s 672ms/step - loss: 0.0057 - accuracy: 0.9918 - val_loss: 0.2531 - val_accuracy: 0.8540
# Epoch 52/75
# 12/12 [==============================] - 8s 658ms/step - loss: 0.0056 - accuracy: 0.9904 - val_loss: 0.2227 - val_accuracy: 0.8676
# Epoch 53/75
# 12/12 [==============================] - 8s 669ms/step - loss: 0.0053 - accuracy: 0.9930 - val_loss: 0.2184 - val_accuracy: 0.8611
# Epoch 54/75
# 12/12 [==============================] - 8s 659ms/step - loss: 0.0025 - accuracy: 0.9958 - val_loss: 0.2299 - val_accuracy: 0.8585
# Epoch 55/75
# 12/12 [==============================] - 8s 670ms/step - loss: 0.0043 - accuracy: 0.9922 - val_loss: 0.2487 - val_accuracy: 0.8605
# Epoch 56/75
# 12/12 [==============================] - 9s 758ms/step - loss: 0.0046 - accuracy: 0.9940 - val_loss: 0.2421 - val_accuracy: 0.8644
# Epoch 57/75
# 12/12 [==============================] - 9s 766ms/step - loss: 0.0036 - accuracy: 0.9948 - val_loss: 0.2679 - val_accuracy: 0.8637
# Epoch 58/75
# 12/12 [==============================] - 9s 770ms/step - loss: 0.0067 - accuracy: 0.9882 - val_loss: 0.2274 - val_accuracy: 0.8644
# Epoch 59/75
# 12/12 [==============================] - 9s 757ms/step - loss: 0.0048 - accuracy: 0.9925 - val_loss: 0.2338 - val_accuracy: 0.8644
# Epoch 60/75
# 12/12 [==============================] - 9s 769ms/step - loss: 0.0041 - accuracy: 0.9942 - val_loss: 0.2448 - val_accuracy: 0.8631
# Epoch 61/75
# 12/12 [==============================] - 10s 805ms/step - loss: 0.0028 - accuracy: 0.9957 - val_loss: 0.2312 - val_accuracy: 0.8618
# Epoch 62/75
# 12/12 [==============================] - 10s 820ms/step - loss: 0.0046 - accuracy: 0.9928 - val_loss: 0.2530 - val_accuracy: 0.8631
# Epoch 63/75
# 12/12 [==============================] - 9s 781ms/step - loss: 0.0042 - accuracy: 0.9929 - val_loss: 0.2396 - val_accuracy: 0.8670
# Epoch 64/75
# 12/12 [==============================] - 10s 799ms/step - loss: 0.0046 - accuracy: 0.9933 - val_loss: 0.2391 - val_accuracy: 0.8631
# Epoch 65/75
# 12/12 [==============================] - 9s 785ms/step - loss: 0.0040 - accuracy: 0.9936 - val_loss: 0.2523 - val_accuracy: 0.8644
# Epoch 66/75
# 12/12 [==============================] - 10s 808ms/step - loss: 0.0040 - accuracy: 0.9937 - val_loss: 0.2264 - val_accuracy: 0.8709
# Epoch 67/75
# 12/12 [==============================] - 10s 818ms/step - loss: 0.0032 - accuracy: 0.9953 - val_loss: 0.2322 - val_accuracy: 0.8676
# Epoch 68/75
# 12/12 [==============================] - 10s 810ms/step - loss: 0.0037 - accuracy: 0.9942 - val_loss: 0.2621 - val_accuracy: 0.8624
# Epoch 69/75
# 12/12 [==============================] - 10s 825ms/step - loss: 0.0025 - accuracy: 0.9975 - val_loss: 0.2793 - val_accuracy: 0.8559
# Epoch 70/75
# 12/12 [==============================] - 9s 794ms/step - loss: 0.0038 - accuracy: 0.9953 - val_loss: 0.2515 - val_accuracy: 0.8644
# Epoch 71/75
# 12/12 [==============================] - 10s 806ms/step - loss: 0.0069 - accuracy: 0.9878 - val_loss: 0.2561 - val_accuracy: 0.8598
# Epoch 72/75
# 12/12 [==============================] - 10s 808ms/step - loss: 0.0034 - accuracy: 0.9952 - val_loss: 0.2571 - val_accuracy: 0.8572
# Epoch 73/75
# 12/12 [==============================] - 10s 809ms/step - loss: 0.0023 - accuracy: 0.9968 - val_loss: 0.2612 - val_accuracy: 0.8598
# Epoch 74/75
# 12/12 [==============================] - 9s 796ms/step - loss: 0.0044 - accuracy: 0.9924 - val_loss: 0.2443 - val_accuracy: 0.8657
# Epoch 75/75
# 12/12 [==============================] - 9s 797ms/step - loss: 0.0027 - accuracy: 0.9948 - val_loss: 0.2321 - val_accuracy: 0.8631
# Iteration:	288
# EMBEDDING:	fasttext
# STOP_WORDS:	False
# LEMMATIZATION:	False
# HIDDEN_DIM:	128
# LSTM_STACK:	False
# DROP_OUT:	False
# SAMPLE_WEIGHTS:	False
# TRAINABLE:	False
#
# Epoch 1/75
# 12/12 [==============================] - 15s 841ms/step - loss: 0.3170 - accuracy: 0.5331 - val_loss: 0.2298 - val_accuracy: 0.7320
# Epoch 2/75
# 12/12 [==============================] - 9s 743ms/step - loss: 0.2465 - accuracy: 0.7352 - val_loss: 0.1840 - val_accuracy: 0.7820
# Epoch 3/75
# 12/12 [==============================] - 9s 772ms/step - loss: 0.2143 - accuracy: 0.7689 - val_loss: 0.1657 - val_accuracy: 0.7884
# Epoch 4/75
# 12/12 [==============================] - 9s 743ms/step - loss: 0.1748 - accuracy: 0.8065 - val_loss: 0.1660 - val_accuracy: 0.7969
# Epoch 5/75
# 12/12 [==============================] - 9s 760ms/step - loss: 0.1478 - accuracy: 0.8444 - val_loss: 0.1443 - val_accuracy: 0.8313
# Epoch 6/75
# 12/12 [==============================] - 9s 761ms/step - loss: 0.1415 - accuracy: 0.8534 - val_loss: 0.1487 - val_accuracy: 0.8151
# Epoch 7/75
# 12/12 [==============================] - 9s 761ms/step - loss: 0.1264 - accuracy: 0.8594 - val_loss: 0.1377 - val_accuracy: 0.8339
# Epoch 8/75
# 12/12 [==============================] - 9s 734ms/step - loss: 0.1210 - accuracy: 0.8826 - val_loss: 0.1491 - val_accuracy: 0.8274
# Epoch 9/75
# 12/12 [==============================] - 9s 731ms/step - loss: 0.1037 - accuracy: 0.8933 - val_loss: 0.1445 - val_accuracy: 0.8339
# Epoch 10/75
# 12/12 [==============================] - 9s 731ms/step - loss: 0.0986 - accuracy: 0.8930 - val_loss: 0.1352 - val_accuracy: 0.8488
# Epoch 11/75
# 12/12 [==============================] - 9s 727ms/step - loss: 0.0855 - accuracy: 0.9183 - val_loss: 0.1472 - val_accuracy: 0.8202
# Epoch 12/75
# 12/12 [==============================] - 9s 743ms/step - loss: 0.0863 - accuracy: 0.9148 - val_loss: 0.1292 - val_accuracy: 0.8306
# Epoch 13/75
# 12/12 [==============================] - 9s 735ms/step - loss: 0.0774 - accuracy: 0.9275 - val_loss: 0.1373 - val_accuracy: 0.8384
# Epoch 14/75
# 12/12 [==============================] - 9s 761ms/step - loss: 0.0678 - accuracy: 0.9333 - val_loss: 0.1355 - val_accuracy: 0.8397
# Epoch 15/75
# 12/12 [==============================] - 9s 732ms/step - loss: 0.0614 - accuracy: 0.9378 - val_loss: 0.1428 - val_accuracy: 0.8462
# Epoch 16/75
# 12/12 [==============================] - 9s 754ms/step - loss: 0.0637 - accuracy: 0.9401 - val_loss: 0.1559 - val_accuracy: 0.8306
# Epoch 17/75
# 12/12 [==============================] - 9s 754ms/step - loss: 0.0571 - accuracy: 0.9476 - val_loss: 0.1556 - val_accuracy: 0.8300
# Epoch 18/75
# 12/12 [==============================] - 9s 768ms/step - loss: 0.0633 - accuracy: 0.9367 - val_loss: 0.1561 - val_accuracy: 0.8384
# Epoch 19/75
# 12/12 [==============================] - 9s 731ms/step - loss: 0.0531 - accuracy: 0.9509 - val_loss: 0.1594 - val_accuracy: 0.8462
# Epoch 20/75
# 12/12 [==============================] - 9s 776ms/step - loss: 0.0448 - accuracy: 0.9576 - val_loss: 0.1651 - val_accuracy: 0.8482
# Epoch 21/75
# 12/12 [==============================] - 9s 770ms/step - loss: 0.0518 - accuracy: 0.9464 - val_loss: 0.1776 - val_accuracy: 0.8313
# Epoch 22/75
# 12/12 [==============================] - 8s 658ms/step - loss: 0.0434 - accuracy: 0.9606 - val_loss: 0.1493 - val_accuracy: 0.8559
# Epoch 23/75
# 12/12 [==============================] - 8s 633ms/step - loss: 0.0413 - accuracy: 0.9628 - val_loss: 0.1576 - val_accuracy: 0.8592
# Epoch 24/75
# 12/12 [==============================] - 7s 619ms/step - loss: 0.0408 - accuracy: 0.9605 - val_loss: 0.1824 - val_accuracy: 0.8572
# Epoch 25/75
# 12/12 [==============================] - 8s 630ms/step - loss: 0.0373 - accuracy: 0.9640 - val_loss: 0.1652 - val_accuracy: 0.8533
# Epoch 26/75
# 12/12 [==============================] - 8s 680ms/step - loss: 0.0331 - accuracy: 0.9692 - val_loss: 0.1742 - val_accuracy: 0.8449
# Epoch 27/75
# 12/12 [==============================] - 9s 720ms/step - loss: 0.0343 - accuracy: 0.9635 - val_loss: 0.1667 - val_accuracy: 0.8501
# Epoch 28/75
# 12/12 [==============================] - 8s 664ms/step - loss: 0.0299 - accuracy: 0.9743 - val_loss: 0.1773 - val_accuracy: 0.8345
# Epoch 29/75
# 12/12 [==============================] - 8s 629ms/step - loss: 0.0369 - accuracy: 0.9604 - val_loss: 0.1933 - val_accuracy: 0.8540
# Epoch 30/75
# 12/12 [==============================] - 7s 615ms/step - loss: 0.0296 - accuracy: 0.9716 - val_loss: 0.1809 - val_accuracy: 0.8598
# Epoch 31/75
# 12/12 [==============================] - 7s 614ms/step - loss: 0.0246 - accuracy: 0.9768 - val_loss: 0.1772 - val_accuracy: 0.8618
# Epoch 32/75
# 12/12 [==============================] - 7s 626ms/step - loss: 0.0247 - accuracy: 0.9782 - val_loss: 0.1803 - val_accuracy: 0.8449
# Epoch 33/75
# 12/12 [==============================] - 7s 617ms/step - loss: 0.0254 - accuracy: 0.9775 - val_loss: 0.1851 - val_accuracy: 0.8592
# Epoch 34/75
# 12/12 [==============================] - 7s 623ms/step - loss: 0.0226 - accuracy: 0.9774 - val_loss: 0.1867 - val_accuracy: 0.8559
# Epoch 35/75
# 12/12 [==============================] - 7s 621ms/step - loss: 0.0207 - accuracy: 0.9813 - val_loss: 0.1630 - val_accuracy: 0.8585
# Epoch 36/75
# 12/12 [==============================] - 8s 632ms/step - loss: 0.0236 - accuracy: 0.9765 - val_loss: 0.1945 - val_accuracy: 0.8514
# Epoch 37/75
# 12/12 [==============================] - 7s 623ms/step - loss: 0.0181 - accuracy: 0.9828 - val_loss: 0.1918 - val_accuracy: 0.8598
# Epoch 38/75
# 12/12 [==============================] - 7s 628ms/step - loss: 0.0195 - accuracy: 0.9822 - val_loss: 0.1955 - val_accuracy: 0.8605
# Epoch 39/75
# 12/12 [==============================] - 7s 620ms/step - loss: 0.0176 - accuracy: 0.9813 - val_loss: 0.2034 - val_accuracy: 0.8579
# Epoch 40/75
# 12/12 [==============================] - 8s 631ms/step - loss: 0.0176 - accuracy: 0.9835 - val_loss: 0.2250 - val_accuracy: 0.8358
# Epoch 41/75
# 12/12 [==============================] - 7s 615ms/step - loss: 0.0251 - accuracy: 0.9777 - val_loss: 0.1977 - val_accuracy: 0.8579
# Epoch 42/75
# 12/12 [==============================] - 8s 627ms/step - loss: 0.0139 - accuracy: 0.9884 - val_loss: 0.1997 - val_accuracy: 0.8579
# Epoch 43/75
# 12/12 [==============================] - 7s 627ms/step - loss: 0.0152 - accuracy: 0.9830 - val_loss: 0.2137 - val_accuracy: 0.8553
# Epoch 44/75
# 12/12 [==============================] - 7s 626ms/step - loss: 0.0219 - accuracy: 0.9760 - val_loss: 0.2013 - val_accuracy: 0.8598
# Epoch 45/75
# 12/12 [==============================] - 7s 618ms/step - loss: 0.0120 - accuracy: 0.9888 - val_loss: 0.2361 - val_accuracy: 0.8365
# Epoch 46/75
# 12/12 [==============================] - 7s 618ms/step - loss: 0.0188 - accuracy: 0.9785 - val_loss: 0.2195 - val_accuracy: 0.8566
# Epoch 47/75
# 12/12 [==============================] - 8s 632ms/step - loss: 0.0206 - accuracy: 0.9793 - val_loss: 0.1958 - val_accuracy: 0.8637
# Epoch 48/75
# 12/12 [==============================] - 7s 616ms/step - loss: 0.0106 - accuracy: 0.9905 - val_loss: 0.2163 - val_accuracy: 0.8559
# Epoch 49/75
# 12/12 [==============================] - 7s 628ms/step - loss: 0.0117 - accuracy: 0.9891 - val_loss: 0.2358 - val_accuracy: 0.8449
# Epoch 50/75
# 12/12 [==============================] - 7s 625ms/step - loss: 0.0176 - accuracy: 0.9815 - val_loss: 0.2153 - val_accuracy: 0.8611
# Epoch 51/75
# 12/12 [==============================] - 8s 631ms/step - loss: 0.0135 - accuracy: 0.9856 - val_loss: 0.2244 - val_accuracy: 0.8559
# Epoch 52/75
# 12/12 [==============================] - 8s 698ms/step - loss: 0.0152 - accuracy: 0.9843 - val_loss: 0.2232 - val_accuracy: 0.8598
# Epoch 53/75
# 12/12 [==============================] - 9s 778ms/step - loss: 0.0104 - accuracy: 0.9899 - val_loss: 0.2314 - val_accuracy: 0.8559
# Epoch 54/75
# 12/12 [==============================] - 9s 759ms/step - loss: 0.0120 - accuracy: 0.9883 - val_loss: 0.2207 - val_accuracy: 0.8553
# Epoch 55/75
# 12/12 [==============================] - 9s 755ms/step - loss: 0.0109 - accuracy: 0.9887 - val_loss: 0.2291 - val_accuracy: 0.8514
# Epoch 56/75
# 12/12 [==============================] - 9s 745ms/step - loss: 0.0105 - accuracy: 0.9882 - val_loss: 0.2286 - val_accuracy: 0.8540
# Epoch 57/75
# 12/12 [==============================] - 9s 738ms/step - loss: 0.0121 - accuracy: 0.9880 - val_loss: 0.2219 - val_accuracy: 0.8585
# Epoch 58/75
# 12/12 [==============================] - 9s 749ms/step - loss: 0.0111 - accuracy: 0.9883 - val_loss: 0.2306 - val_accuracy: 0.8572
# Epoch 59/75
# 12/12 [==============================] - 9s 740ms/step - loss: 0.0093 - accuracy: 0.9915 - val_loss: 0.2520 - val_accuracy: 0.8514
# Epoch 60/75
# 12/12 [==============================] - 9s 762ms/step - loss: 0.0094 - accuracy: 0.9894 - val_loss: 0.2393 - val_accuracy: 0.8605
# Epoch 61/75
# 12/12 [==============================] - 9s 744ms/step - loss: 0.0091 - accuracy: 0.9914 - val_loss: 0.2254 - val_accuracy: 0.8657
# Epoch 62/75
# 12/12 [==============================] - 9s 749ms/step - loss: 0.0104 - accuracy: 0.9885 - val_loss: 0.2342 - val_accuracy: 0.8475
# Epoch 63/75
# 12/12 [==============================] - 9s 737ms/step - loss: 0.0088 - accuracy: 0.9902 - val_loss: 0.2546 - val_accuracy: 0.8423
# Epoch 64/75
# 12/12 [==============================] - 9s 784ms/step - loss: 0.0157 - accuracy: 0.9836 - val_loss: 0.2401 - val_accuracy: 0.8559
# Epoch 65/75
# 12/12 [==============================] - 9s 756ms/step - loss: 0.0082 - accuracy: 0.9915 - val_loss: 0.2198 - val_accuracy: 0.8663
# Epoch 66/75
# 12/12 [==============================] - 9s 749ms/step - loss: 0.0086 - accuracy: 0.9902 - val_loss: 0.2450 - val_accuracy: 0.8520
# Epoch 67/75
# 12/12 [==============================] - 9s 762ms/step - loss: 0.0072 - accuracy: 0.9943 - val_loss: 0.2413 - val_accuracy: 0.8650
# Epoch 68/75
# 12/12 [==============================] - 9s 753ms/step - loss: 0.0130 - accuracy: 0.9869 - val_loss: 0.2460 - val_accuracy: 0.8579
# Epoch 69/75
# 12/12 [==============================] - 9s 776ms/step - loss: 0.0053 - accuracy: 0.9968 - val_loss: 0.2413 - val_accuracy: 0.8566
# Epoch 70/75
# 12/12 [==============================] - 9s 746ms/step - loss: 0.0086 - accuracy: 0.9929 - val_loss: 0.2435 - val_accuracy: 0.8624
# Epoch 71/75
# 12/12 [==============================] - 9s 770ms/step - loss: 0.0147 - accuracy: 0.9832 - val_loss: 0.2326 - val_accuracy: 0.8572
# Epoch 72/75
# 12/12 [==============================] - 9s 754ms/step - loss: 0.0076 - accuracy: 0.9929 - val_loss: 0.2551 - val_accuracy: 0.8527
# Epoch 73/75
# 12/12 [==============================] - 9s 743ms/step - loss: 0.0055 - accuracy: 0.9949 - val_loss: 0.2379 - val_accuracy: 0.8566
# Epoch 74/75
# 12/12 [==============================] - 9s 759ms/step - loss: 0.0089 - accuracy: 0.9876 - val_loss: 0.2481 - val_accuracy: 0.8572
# Epoch 75/75
# 12/12 [==============================] - 9s 751ms/step - loss: 0.0066 - accuracy: 0.9933 - val_loss: 0.2552 - val_accuracy: 0.8624

# %% [markdown]
# ## Output Model Summary

# %%
# Output Results
# Convert dictionary to dataframe
df_summary = pd.DataFrame(dct_summary)

# Create file path
file_name_text = 'entity_extraction_evaluation_'
time_stamp =  time.strftime("%Y%m%d-%H%M%S")
file_extension = ".csv"
file_name = file_name_text + time_stamp + file_extension
path = os.path.join(path_dir_data, subfolder_b, 
                    subfolder_entity, file_name)

# Save table
df_summary.to_csv(path, index=False)

# %% [markdown]
# ## Visuals

# %% [markdown]
# ### Accuracy Charts

# %%
# hist = pd.DataFrame(history.history)

# #plot training and validation accuracy
# f = plt.figure(figsize=(5,5))
# plt.plot(hist["accuracy"], label =' Training Accuracy')
# plt.plot(hist["val_accuracy"], label = 'Validation Accuracy')
# plt.legend(loc="lower right")
# plt.show()

# # Save and output
# file_name = 'enitity_extraction_training_validation_accuracy.png'
# path = os.path.join(path_dir_data, file_name)
# f.savefig(path)
# # f.download(path)

# %% [markdown]
# ### Confusion Matrix

# %%
# # Create confusion matrix
# cm = confusion_matrix(y_test_fl, y_pred_fl)
# df_cm = pd.DataFrame(cm, columns=np.unique(y_test_fl), index = np.unique(y_pred_fl))
# df_cm.index.name = 'Actual'
# df_cm.columns.name = 'Predicted'

# # Visualize
# plt.figure(figsize = (10,7))
# sn.set(font_scale=1.4)#for label size
# sn.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16})# font size

# %% [markdown]
# # Save and Restore Model
# The following section tests saving and restoring the model.

# %% [markdown]
# ## Save

# %%
# # Export Model
# folder_keras_model = 'entity_extraction_w_processing_keras'
# path_keras_model = os.path.join(path_dir_data, folder_keras_model)

# # SavedModel
# model.save(path_keras_model)

# %% [markdown]
# # Restore

# %%
# from tensorflow import keras
# model = keras.models.load_model(path_keras_model)
